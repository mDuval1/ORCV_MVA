# %%
# %matplotlib notebook
# %load_ext autoreload
# %autoreload 2

# %%
import tqdm

import stable_nalu

from RLfunctions import *
from NAU_RL import *

# %% [markdown]
# # A2C test

# %%
# We load CartPole-v1
env = gym.make('CartPole-v1')
# We wrap it in order to save our experiment on a file.
# env = Monitor(env, "./gym-results", force=True)

# %%
env.reset()
# Out:
# array([ 0.04476103,  0.01527813,  0.03120175, -0.00666392])

# %%
done = False
obs = env.reset()
while not done:
    action = env.action_space.sample()
    obs, reward, done, info = env.step(action)
env.close()
# show_video("./gym-results")

# %%
env_id = 'CartPole-v1'
value_learning_rate = 0.001
actor_learning_rate = 0.001
gamma = 0.99
entropy = 1
seed = 1

config_a2c = {
    'env_id': env_id,
    'gamma': gamma,
    'seed': seed,
    'value_network': {'learning_rate': value_learning_rate},
    'actor_network': {'learning_rate': actor_learning_rate},
    'entropy': entropy
}

print("Current config_a2c is:")
pprint(config_a2c)
# Out:
# Current config_a2c is:
# {'actor_network': {'learning_rate': 0.001},
#  'entropy': 1,
#  'env_id': 'CartPole-v1',
#  'gamma': 0.99,
#  'seed': 1,
#  'value_network': {'learning_rate': 0.001}}

# %%
agent = A2CAgent(config_a2c)
rewards = agent.training_batch(1000, 256)
# Out:
# Epoch 0/1000: Mean rewards: 19.86, Std: 9.84
# Epoch 50/1000: Mean rewards: 29.72, Std: 14.12
# Epoch 100/1000: Mean rewards: 49.22, Std: 21.84
# Epoch 150/1000: Mean rewards: 71.0, Std: 43.98
# Epoch 200/1000: Mean rewards: 127.32, Std: 66.05
# Epoch 250/1000: Mean rewards: 227.68, Std: 98.54
# Epoch 300/1000: Mean rewards: 171.5, Std: 52.76
# Epoch 350/1000: Mean rewards: 243.54, Std: 96.6
# Epoch 400/1000: Mean rewards: 292.16, Std: 114.83
# Epoch 450/1000: Mean rewards: 375.92, Std: 118.82
# Epoch 500/1000: Mean rewards: 406.0, Std: 107.45
# Epoch 550/1000: Mean rewards: 406.9, Std: 94.07
# Epoch 600/1000: Mean rewards: 425.96, Std: 90.8
# Epoch 650/1000: Mean rewards: 430.36, Std: 95.74
# Epoch 700/1000: Mean rewards: 410.96, Std: 103.09
# Epoch 750/1000: Mean rewards: 442.92, Std: 95.76
# Epoch 800/1000: Mean rewards: 449.72, Std: 103.0
# Epoch 850/1000: Mean rewards: 474.68, Std: 65.76
# Epoch 900/1000: Mean rewards: 483.22, Std: 63.72
# Epoch 950/1000: Mean rewards: 462.56, Std: 91.68
# Epoch 999/1000: Mean rewards: 479.74, Std: 61.16
# <img src="data:image/png;base64,..." width="639.9999861283738">
# The trainnig was done over a total of 1780 episodes

# %%
agent.evaluate(render=True)
# Out:
# <video alt="gym-results\openaigym.video.6.4120.video000000.mp4" autoplay
#                       loop controls style="height: 400px;">
#                       <source src="data:video/mp4;base64,..." type="video/mp4" />
#                  </video>
# Reward: 500.0
# 500.0

# %% [markdown]
# # Training with random mass

# %%
env_id = 'CartPole-v1'
value_learning_rate = 0.001
actor_learning_rate = 0.001
gamma = 0.99
entropy = 1
seed = 1

config_a2c = {
    'env_id': env_id,
    'gamma': gamma,
    'seed': seed,
    'value_network': {'learning_rate': value_learning_rate},
    'actor_network': {'learning_rate': actor_learning_rate},
    'entropy': entropy
}

print("Current config_a2c is:")
pprint(config_a2c)
# Out:
# Current config_a2c is:
# {'actor_network': {'learning_rate': 0.001},
#  'entropy': 1,
#  'env_id': 'CartPole-v1',
#  'gamma': 0.99,
#  'seed': 1,
#  'value_network': {'learning_rate': 0.001}}

# %%
agent = A2CAgentRandom(config_a2c, range_train=(0.05, 0.2), range_eval=(0.05, 0.2))
rewards = agent.training_batch(1000, 256)
# Out:
# Epoch 0/1000: Mean rewards: 22.82, Std: 10.64
# Epoch 50/1000: Mean rewards: 34.94, Std: 18.3
# Epoch 100/1000: Mean rewards: 57.3, Std: 31.81
# Epoch 150/1000: Mean rewards: 119.84, Std: 80.03
# Epoch 200/1000: Mean rewards: 155.64, Std: 55.7
# Epoch 250/1000: Mean rewards: 248.24, Std: 114.74
# Epoch 300/1000: Mean rewards: 292.92, Std: 136.28
# Epoch 350/1000: Mean rewards: 323.82, Std: 126.6
# Epoch 400/1000: Mean rewards: 357.94, Std: 115.53
# Epoch 450/1000: Mean rewards: 395.98, Std: 106.74
# Epoch 500/1000: Mean rewards: 248.38, Std: 69.47
# Epoch 550/1000: Mean rewards: 445.48, Std: 83.39
# Epoch 600/1000: Mean rewards: 445.7, Std: 81.67
# Epoch 650/1000: Mean rewards: 445.08, Std: 106.29
# Epoch 700/1000: Mean rewards: 467.58, Std: 74.4
# Epoch 750/1000: Mean rewards: 463.44, Std: 81.36
# Epoch 800/1000: Mean rewards: 459.58, Std: 96.22
# Epoch 850/1000: Mean rewards: 444.52, Std: 93.33
# Epoch 900/1000: Mean rewards: 459.62, Std: 81.48
# Epoch 950/1000: Mean rewards: 496.82, Std: 15.69
# Early stopping !
# <img src="data:image/png;base64,..." width="NaN">
# The trainnig was done over a total of 1431 episodes

# %%
def eval_agent(agent, n_eval, min_mass, max_mass):
    rws = []
    for _ in tqdm.tqdm_notebook(range(n_eval)):
        r = agent.evaluate(min_mass, max_mass)
        rws.append(r)
    rws = np.array(rws)
    print(f'Mean success : {rws.mean():.2f} +- {rws.std():.2f}')

# %%
eval_agent(agent, 100, 0.05, 0.2)
# Out:
# C:\tools\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   This is separate from the ipykernel package so we can avoid doing imports until
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# Mean success : 487.68 +- 42.30

# %%
eval_agent(agent, 100, 0.2, 0.5)
# Out:
# C:\tools\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   This is separate from the ipykernel package so we can avoid doing imports until
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# Mean success : 478.49 +- 58.00

# %%
eval_agent(agent, 100, 0.2, 1)
# Out:
# C:\tools\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   This is separate from the ipykernel package so we can avoid doing imports until
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# Mean success : 451.28 +- 89.90

# %%
eval_agent(agent, 100, 0.5, 2)
# Out:
# C:\tools\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   This is separate from the ipykernel package so we can avoid doing imports until
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# Mean success : 184.08 +- 206.71

# %%
eval_agent(agent, 100, 1, 5)
# Out:
# C:\tools\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   This is separate from the ipykernel package so we can avoid doing imports until
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# Mean success : 25.78 +- 58.29

# %% [markdown]
# # NAU agent

# %% [markdown]
# ## Layers

# %%
l = stable_nalu.layer.GeneralizedLayer(5, 10, 'ReRegualizedLinearMNAC')

# %%
l
# Out:
# GeneralizedLayer(
#   in_features=5, out_features=10, unit_name=ReRegualizedLinearMNAC
#   (layer): ReRegualizedLinearMNACLayer(in_features=5, out_features=10)
# )

# %%
l(torch.rand(16, 5)).shape
# Out:
# torch.Size([16, 10])

# %% [markdown]
# ## RNN

# %% [markdown]
# ### Functions

# %%
class ValueNetworkNAURNN(stable_nalu.abstract.ExtendedTorchModule):
    UNIT_NAMES = stable_nalu.layer.GeneralizedCell.UNIT_NAMES

    def __init__(self, unit_name, input_size=5, hidden_size=16, **kwargs):
        super().__init__('network', writer=None, **kwargs)

        self.unit_name = unit_name
        self.input_size = input_size
        self.hidden_size = hidden_size

        # Since for the 'mul' problem, the zero_state should be 1, and for the
        # 'add' problem it should be 0. The zero_states are allowed to be
        # # optimized.
        if unit_name == 'LSTM':
            self.zero_state = torch.nn.ParameterDict({
                'h_t0': torch.nn.Parameter(torch.Tensor(self.hidden_size)),
                'c_t0': torch.nn.Parameter(torch.Tensor(self.hidden_size))
            })
        else:
            self.zero_state = torch.nn.Parameter(torch.Tensor(self.hidden_size))

        self.recurent_cell = stable_nalu.layer.GeneralizedCell(input_size, self.hidden_size,
                                             unit_name,
                                             writer=self.writer,
                                             name='recurrent_layer',
                                             **kwargs)
        self.output_layer = stable_nalu.layer.GeneralizedLayer(self.hidden_size, 1,
                                            'linear'
                                                if unit_name in {'GRU', 'LSTM', 'RNN-tanh', 'RNN-ReLU'}
                                                else unit_name,
                                             writer=self.writer,
                                             name='output_layer',
                                             **kwargs)
        self.reset_parameters()

    def reset_parameters(self):
        if self.unit_name == 'LSTM':
            for zero_state in self.zero_state.values():
                torch.nn.init.zeros_(zero_state)
        else:
            torch.nn.init.zeros_(self.zero_state)

        self.recurent_cell.reset_parameters()
        self.output_layer.reset_parameters()

    def forward(self, x):
        """Performs recurrent iterations over the input.

        Arguments:
            input: Expected to have the shape [obs, time, dims]
        """
        if len(x.size()) == 2:
            x = x[None]
        # Perform recurrent iterations over the input
        if self.unit_name == 'LSTM':
            h_tm1 = tuple(zero_state.repeat(x.size(0), 1) for zero_state in self.zero_state.values())
        else:
            h_tm1 = self.zero_state.repeat(x.size(0), 1)

        hs = []
        for t in range(x.size(1)):
            x_t = x[:, t]
            h_t = self.recurent_cell(x_t, h_tm1)
            h_tm1 = h_t
            hs.append(h_t)

        # Grap the final hidden output and use as the output from the recurrent layer
#         z_1 = h_t[0] if self.unit_name == 'LSTM' else h_t
        z = [x[0] if self.unit_name == 'LSTM' else x for x in hs]
#         z_2 = self.output_layer(z_1)
        z_2 = self.output_layer(torch.stack(z))
        return z_2

    def extra_repr(self):
        return 'unit_name={}, input_size={}'.format(
            self.unit_name, self.input_size
        )
    
    def predict(self, x):
        return self(x).detach().numpy()

# %%
VR = ValueNetworkNAURNN('ReRegualizedLinearMNAC')

# %%
VR(torch.rand(1, 200, 5)).shape
# Out:
# torch.Size([200, 1])

# %%
VR.predict(torch.rand(200, 5))
# Out:
# array([[2.4869887e-06],
#        [2.4870126e-06],
#        [2.4869582e-06],
#        [2.4869546e-06],
#        [2.4869601e-06],
#        [2.4869312e-06],
#        [2.4872702e-06],
#        [2.4869012e-06],
#        [2.4870947e-06],
#        [2.4869253e-06],
#        [2.4870726e-06],
#        [2.4869662e-06],
#        [2.4869037e-06],
#        [2.4870192e-06],
#        [2.4868966e-06],
#        [2.4868771e-06],
#        [2.4869339e-06],
#        [2.4869769e-06],
#        [2.4868914e-06],
#        [2.4869955e-06],
#        [2.4869169e-06],
#        [2.4869341e-06],
#        [2.4868607e-06],
#        [2.4869876e-06],
#        [2.4870126e-06],
#        [2.4868677e-06],
#        [2.4869921e-06],
#        [2.4868757e-06],
#        [2.4869059e-06],
#        [2.4868543e-06],
#        [2.4871088e-06],
#        [2.4868746e-06],
#        [2.4868730e-06],
#        [2.4868978e-06],
#        [2.4869737e-06],
#        [2.4869173e-06],
#        [2.4870071e-06],
#        [2.4868766e-06],
#        [2.4869544e-06],
#        [2.4870842e-06],
#        [2.4868746e-06],
#        [2.4870008e-06],
#        [2.4868966e-06],
#        [2.4869021e-06],
#        [2.4869335e-06],
#        [2.4868827e-06],
#        [2.4868946e-06],
#        [2.4869757e-06],
#        [2.4868573e-06],
#        [2.4869848e-06],
#        [2.4869967e-06],
#        [2.4870399e-06],
#        [2.4870562e-06],
#        [2.4869466e-06],
#        [2.4868914e-06],
#        [2.4869121e-06],
#        [2.4869214e-06],
#        [2.4869962e-06],
#        [2.4869212e-06],
#        [2.4868582e-06],
#        [2.4870640e-06],
#        [2.4869921e-06],
#        [2.4868700e-06],
#        [2.4869976e-06],
#        [2.4869814e-06],
#        [2.4869566e-06],
#        [2.4869544e-06],
#        [2.4869389e-06],
#        [2.4869234e-06],
#        [2.4869232e-06],
#        [2.4869144e-06],
#        [2.4869591e-06],
#        [2.4868907e-06],
#        [2.4869096e-06],
#        [2.4869291e-06],
#        [2.4868643e-06],
#        [2.4868730e-06],
#        [2.4871267e-06],
#        [2.4869632e-06],
#        [2.4869469e-06],
#        [2.4869200e-06],
#        [2.4869053e-06],
#        [2.4869958e-06],
#        [2.4868837e-06],
#        [2.4868880e-06],
#        [2.4868723e-06],
#        [2.4868941e-06],
#        [2.4868903e-06],
#        [2.4871026e-06],
#        [2.4869353e-06],
#        [2.4868514e-06],
#        [2.4869430e-06],
#        [2.4869389e-06],
#        [2.4868716e-06],
#        [2.4868687e-06],
#        [2.4869503e-06],
#        [2.4869721e-06],
#        [2.4869444e-06],
#        [2.4869200e-06],
#        [2.4868573e-06],
#        [2.4869246e-06],
#        [2.4870706e-06],
#        [2.4869355e-06],
#        [2.4870001e-06],
#        [2.4869692e-06],
#        [2.4870071e-06],
#        [2.4869594e-06],
#        [2.4871044e-06],
#        [2.4870430e-06],
#        [2.4869196e-06],
#        [2.4868973e-06],
#        [2.4869048e-06],
#        [2.4869030e-06],
#        [2.4870062e-06],
#        [2.4869344e-06],
#        [2.4869366e-06],
#        [2.4868625e-06],
#        [2.4869178e-06],
#        [2.4870458e-06],
#        [2.4869939e-06],
#        [2.4868568e-06],
#        [2.4869662e-06],
#        [2.4869328e-06],
#        [2.4868973e-06],
#        [2.4869260e-06],
#        [2.4869628e-06],
#        [2.4869425e-06],
#        [2.4870637e-06],
#        [2.4868955e-06],
#        [2.4870972e-06],
#        [2.4870210e-06],
#        [2.4868968e-06],
#        [2.4869728e-06],
#        [2.4868673e-06],
#        [2.4868859e-06],
#        [2.4869096e-06],
#        [2.4869896e-06],
#        [2.4869016e-06],
#        [2.4868962e-06],
#        [2.4869901e-06],
#        [2.4869626e-06],
#        [2.4868664e-06],
#        [2.4868898e-06],
#        [2.4869119e-06],
#        [2.4868632e-06],
#        [2.4869219e-06],
#        [2.4869776e-06],
#        [2.4868882e-06],
#        [2.4868841e-06],
#        [2.4869269e-06],
#        [2.4869100e-06],
#        [2.4869851e-06],
#        [2.4868564e-06],
#        [2.4869200e-06],
#        [2.4869787e-06],
#        [2.4869992e-06],
#        [2.4869289e-06],
#        [2.4869400e-06],
#        [2.4869178e-06],
#        [2.4869989e-06],
#        [2.4871158e-06],
#        [2.4869078e-06],
#        [2.4869498e-06],
#        [2.4869414e-06],
#        [2.4870626e-06],
#        [2.4869053e-06],
#        [2.4871013e-06],
#        [2.4869059e-06],
#        [2.4869792e-06],
#        [2.4869034e-06],
#        [2.4869662e-06],
#        [2.4869134e-06],
#        [2.4868752e-06],
#        [2.4869269e-06],
#        [2.4869257e-06],
#        [2.4869253e-06],
#        [2.4869814e-06],
#        [2.4868966e-06],
#        [2.4872199e-06],
#        [2.4869098e-06],
#        [2.4868712e-06],
#        [2.4869325e-06],
#        [2.4868964e-06],
#        [2.4869180e-06],
#        [2.4868607e-06],
#        [2.4869169e-06],
#        [2.4869164e-06],
#        [2.4869234e-06],
#        [2.4869460e-06],
#        [2.4869430e-06],
#        [2.4868971e-06],
#        [2.4870819e-06],
#        [2.4869269e-06],
#        [2.4868978e-06],
#        [2.4870108e-06],
#        [2.4869250e-06],
#        [2.4869828e-06],
#        [2.4869614e-06],
#        [2.4869064e-06],
#        [2.4872149e-06]], dtype=float32)

# %%
a = VR.regualizer()

# %%
a['W']
# Out:
# tensor(0.1034, grad_fn=<AddBackward0>)

# %%
hasattr(VR, 'regualizer')
# Out:
# True

# %%
class A2CAgentRNN(A2CAgentRandom):

    def __init__(self, config, range_train, range_eval, a_net, v_net, LSTM=False, reg=100):
        super(A2CAgentRNN, self).__init__(config, range_train, range_eval)
        self.value_network = v_net
        self.actor_network = a_net
        self.value_network_optimizer = optim.RMSprop(self.value_network.parameters(),
                                                     lr=config['value_network']['learning_rate'])
        self.actor_network_optimizer = optim.RMSprop(self.actor_network.parameters(),
                                                     lr=config['actor_network']['learning_rate'])
        self.recurrent = LSTM
        self.lambda_reg = reg
        
    def optimize_model(self, observations, actions, returns, advantages, nb_traj):
        # Optimize value function
        # MSE for the values
        Vs_current = self.value_network(torch.tensor(observations, dtype=torch.float)).flatten()
        loss_value = F.mse_loss(Vs_current, torch.tensor(returns, dtype=torch.float))
        if hasattr(self.value_network, 'regualizer'):
            loss_value += self.value_network.regualizer()['W']
        self.value_network_optimizer.zero_grad()
        loss_value.backward()
        self.value_network_optimizer.step()

        # Actor & Entropy loss
        Policies = self.actor_network(torch.tensor(observations, dtype=torch.float))
        Policies_action = torch.stack([x[actions[i]] for i, x in enumerate(Policies)])
        loss_action = - torch.sum(torch.tensor(advantages, dtype=torch.float) * torch.log(Policies_action) +  # actor
                                  0.001 * Policies_action * torch.log(Policies_action)) / nb_traj # entropy
        if hasattr(self.actor_network, 'regualizer'):
            loss_action += self.actor_network.regualizer()['W']
        self.actor_network_optimizer.zero_grad()
        loss_action.backward()
        self.actor_network_optimizer.step()
        
    def training_batch(self, epochs, batch_size):
        """Perform a training by batch

        Parameters
        ----------
        epochs : int
            Number of epochs
        batch_size : int
            The size of a batch
        """
        episode_count = 0
        actions = np.empty((batch_size,), dtype=np.int)
        dones = np.empty((batch_size,), dtype=np.bool)
        rewards, values = np.empty((2, batch_size), dtype=np.float)
        observations = np.empty((batch_size,) + (self.env.observation_space.shape[0]+1, ), dtype=np.float)
        observation = self.env.reset()
        rewards_test = []

        for epoch in range(epochs):
            # Lets collect one batch
            for i in range(batch_size):
                observations[i] = observation
                actions[i] = self.actor_network.select_action(torch.tensor(observations[i] , dtype=torch.float))
#                 values[i] = self.value_network.predict(torch.tensor(observations[i] , dtype=torch.float))
                # step
                observation, reward, done, _ = self.env.step(actions[i])
                if len(observation) == self.env.observation_space.shape[0]:
                    observation = np.insert(observation, len(observation), self.env.mass)
                dones[i] = done
                rewards[i] = reward
                if dones[i]:
                    observation = self.env.reset()
#                 print(self.env.mass)
            
            all_observe = torch.tensor(np.concatenate((observations, observation[None])), dtype=torch.float)
            all_values = self.value_network.predict(all_observe)
            values = all_values[:-1]

            # If our episode didn't end on the last step we need to compute the value for the last state
            if dones[-1]:
                next_value = 0
            else:
                next_value = all_values[-1]

            # Update episode_count
            episode_count += sum(dones)

            # Compute returns and advantages
            returns, advantages = self._returns_advantages(rewards, dones, values, next_value)

            # Learning step !
            self.optimize_model(observations, actions, returns, advantages, max(1, sum(dones)))

            # Test it every 50 epochs
            if epoch % 50 == 0 or epoch == epochs - 1:
                rewards_test.append(np.array([self.evaluate(*self.range_eval) for _ in range(50)]))
                print(f'Epoch {epoch}/{epochs}: Mean rewards: {round(rewards_test[-1].mean(), 2)}, Std: {round(rewards_test[-1].std(), 2)}')

                # Early stopping
                if rewards_test[-1].mean() > 490 and epoch != epochs -1:
                    print('Early stopping !')
                    break
                observation = self.env.reset()
                    
        # Plotting
        plt.figure()
        r = pd.DataFrame((itertools.chain(*(itertools.product([i], rewards_test[i]) for i in range(len(rewards_test))))), columns=['Epoch', 'Reward'])
        sns.lineplot(x="Epoch", y="Reward", data=r, ci='sd')
        
        print(f'The training was done over a total of {episode_count} episodes')

# %% [markdown]
# ### Training

# %%
env_id = 'CartPole-v1'
value_learning_rate = 0.001
actor_learning_rate = 0.001
gamma = 0.99
entropy = 1
seed = 1

config_a2c = {
    'env_id': env_id,
    'gamma': gamma,
    'seed': seed,
    'value_network': {'learning_rate': value_learning_rate},
    'actor_network': {'learning_rate': actor_learning_rate},
    'entropy': entropy
}

print("Current config_a2c is:")
pprint(config_a2c)
# Out:
# Current config_a2c is:
# {'actor_network': {'learning_rate': 0.001},
#  'entropy': 1,
#  'env_id': 'CartPole-v1',
#  'gamma': 0.99,
#  'seed': 1,
#  'value_network': {'learning_rate': 0.001}}

# %%
a_net = ActorNetworkNAU(agent.env.observation_space.shape[0] + 1, 16, agent.env.action_space.n)
# v_net = ValueNetworkNAU(agent.env.observation_space.shape[0] + 1, 16, 1)
v_net = ValueNetworkNAURNN('ReRegualizedLinearMNAC', input_size=5, hidden_size=16)

# %%
agent = A2CAgentRNN(config_a2c, range_train=(0.05, 0.2), range_eval=(0.05, 0.2),
                    a_net=a_net, v_net=v_net, LSTM=True, reg=100)
# agent = A2CAgentRNN(config_a2c, range_train=(0.05, 0.2), range_eval=(0.05, 0.2),
#                     a_net=a_net, v_net=v_net, LSTM=False, reg=100)

# %%
rewards = agent.training_batch(1000, 256)
# Out:
# Epoch 0/1000: Mean rewards: 18.3, Std: 7.45
# Epoch 50/1000: Mean rewards: 53.56, Std: 27.02
# Epoch 100/1000: Mean rewards: 106.56, Std: 54.58
# Epoch 150/1000: Mean rewards: 225.8, Std: 110.97
# Epoch 200/1000: Mean rewards: 200.88, Std: 101.24
# Epoch 250/1000: Mean rewards: 310.2, Std: 136.16
# Epoch 300/1000: Mean rewards: 317.36, Std: 129.57
# Epoch 350/1000: Mean rewards: 308.86, Std: 144.96
# Epoch 400/1000: Mean rewards: 374.38, Std: 139.84
# Epoch 450/1000: Mean rewards: 356.18, Std: 141.48
# Epoch 500/1000: Mean rewards: 359.6, Std: 152.46
# Epoch 550/1000: Mean rewards: 381.22, Std: 149.11
# Epoch 600/1000: Mean rewards: 428.58, Std: 112.55
# Epoch 650/1000: Mean rewards: 451.4, Std: 94.26
# Epoch 700/1000: Mean rewards: 477.84, Std: 74.46
# Epoch 750/1000: Mean rewards: 457.76, Std: 102.87
# Epoch 800/1000: Mean rewards: 464.34, Std: 87.82
# Epoch 850/1000: Mean rewards: 459.68, Std: 105.16
# Epoch 900/1000: Mean rewards: 399.42, Std: 108.18
# Epoch 950/1000: Mean rewards: 485.22, Std: 59.8
# Epoch 999/1000: Mean rewards: 487.76, Std: 54.06
# <img src="data:image/png;base64,..." width="639.9999861283738">
# The training was done over a total of 1285 episodes

# %% [markdown]
# ### Evaluation

# %%
eval_agent(agent, 100, 0.05, 0.2)
# Out:
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# Mean success : 472.55 +- 78.70

# %%
eval_agent(agent, 100, 0.2, 0.5)
# Out:
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# Mean success : 463.74 +- 94.31

# %%
eval_agent(agent, 100, 0.2, 1)
# Out:
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# Mean success : 424.26 +- 108.26

# %%
eval_agent(agent, 100, 0.5, 2)
# Out:
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# Mean success : 198.37 +- 200.21

# %%
eval_agent(agent, 100, 1, 5)
# Out:
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# Mean success : 32.79 +- 57.86

# %% [markdown]
# ## Both using NAU

# %% [markdown]
# ### Functions

# %%
class NetworkNAURNN(stable_nalu.abstract.ExtendedTorchModule):
    UNIT_NAMES = stable_nalu.layer.GeneralizedCell.UNIT_NAMES

    def __init__(self, unit_name, input_size=5, hidden_size=16, output_size=1, **kwargs):
        super().__init__('network', writer=None, **kwargs)

        self.unit_name = unit_name
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.output_size = output_size

        # Since for the 'mul' problem, the zero_state should be 1, and for the
        # 'add' problem it should be 0. The zero_states are allowed to be
        # # optimized.
        if unit_name == 'LSTM':
            self.zero_state = torch.nn.ParameterDict({
                'h_t0': torch.nn.Parameter(torch.Tensor(self.hidden_size)),
                'c_t0': torch.nn.Parameter(torch.Tensor(self.hidden_size))
            })
        else:
            self.zero_state = torch.nn.Parameter(torch.Tensor(self.hidden_size))

        self.recurent_cell = stable_nalu.layer.GeneralizedCell(input_size, self.hidden_size,
                                             unit_name,
                                             writer=self.writer,
                                             name='recurrent_layer',
                                             **kwargs)
        self.output_layer = stable_nalu.layer.GeneralizedLayer(self.hidden_size, output_size,
                                            'linear'
                                                if unit_name in {'GRU', 'LSTM', 'RNN-tanh', 'RNN-ReLU'}
                                                else unit_name,
                                             writer=self.writer,
                                             name='output_layer',
                                             **kwargs)
        self.reset_parameters()

    def reset_parameters(self):
        if self.unit_name == 'LSTM':
            for zero_state in self.zero_state.values():
                torch.nn.init.zeros_(zero_state)
        else:
            torch.nn.init.zeros_(self.zero_state)

        self.recurent_cell.reset_parameters()
        self.output_layer.reset_parameters()

    def forward(self, x):
        """Performs recurrent iterations over the input.

        Arguments:
            input: Expected to have the shape [obs, time, dims]
        """
        if len(x.size()) == 2:
            x = x[None]
        # Perform recurrent iterations over the input
        if self.unit_name == 'LSTM':
            h_tm1 = tuple(zero_state.repeat(x.size(0), 1) for zero_state in self.zero_state.values())
        else:
            h_tm1 = self.zero_state.repeat(x.size(0), 1)

        hs = []
        for t in range(x.size(1)):
            x_t = x[:, t]
            h_t = self.recurent_cell(x_t, h_tm1)
            h_tm1 = h_t
            hs.append(h_t)

        # Grap the final hidden output and use as the output from the recurrent layer
#         z_1 = h_t[0] if self.unit_name == 'LSTM' else h_t
        z = [x[0] if self.unit_name == 'LSTM' else x for x in hs]
#         z_2 = self.output_layer(z_1)
        z_2 = self.output_layer(torch.stack(z))
        return z_2

    def extra_repr(self):
        return 'unit_name={}, input_size={}'.format(
            self.unit_name, self.input_size
        )
    
    def predict(self, x):
        return self(x).detach().numpy()

# %%
class NetworkNAU(stable_nalu.abstract.ExtendedTorchModule):
    UNIT_NAMES = stable_nalu.layer.GeneralizedLayer.UNIT_NAMES

    def __init__(self, unit_name, input_size=100, hidden_size=2, first_layer=None, nac_mul='none', 
                 output_size=1, eps=1e-7, writer=None, actor=False, **kwargs):
        super().__init__('network', writer=writer, **kwargs)
        self.unit_name = unit_name
        self.input_size = input_size
        self.output_size = output_size
        self.hidden_size = hidden_size
        self.nac_mul = nac_mul
        self.eps = eps
        self.actor = actor

        if first_layer is not None:
            unit_name_1 = first_layer
        else:
            unit_name_1 = unit_name

        self.layer_1 = stable_nalu.layer.GeneralizedLayer(input_size, hidden_size,
                                        unit_name_1,
                                        writer=self.writer,
                                        name='layer_1',
                                        eps=eps, **kwargs)

        if nac_mul == 'mnac':
            unit_name_2 = unit_name[0:-3] + 'MNAC'
        else:
            unit_name_2 = unit_name

        self.layer_2 = stable_nalu.layer.GeneralizedLayer(hidden_size, 1,
                                        'linear' if unit_name_2 in stable_nalu.layer.BasicLayer.ACTIVATIONS else unit_name_2,
                                        writer=self.writer,
                                        name='layer_2',
                                        eps=eps, **kwargs)
        self.reset_parameters()
        self.z_1_stored = None

    def reset_parameters(self):
        self.layer_1.reset_parameters()
        self.layer_2.reset_parameters()

    def regualizer(self):
        if self.nac_mul == 'max-safe':
            return super().regualizer({
                'z': torch.mean(torch.relu(1 - self.z_1_stored))
            })
        else:
            return super().regualizer()

    def forward(self, input):
        if self.actor:
            if len(input.size()) == 1:
                input = input[None]
        self.writer.add_summary('x', input)
        z_1 = self.layer_1(input)
        self.z_1_stored = z_1
        self.writer.add_summary('z_1', z_1)

        if self.nac_mul == 'none' or self.nac_mul == 'mnac':
            z_2 = self.layer_2(z_1)
        elif self.nac_mul == 'normal':
            z_2 = torch.exp(self.layer_2(torch.log(torch.abs(z_1) + self.eps)))
        elif self.nac_mul == 'safe':
            z_2 = torch.exp(self.layer_2(torch.log(torch.abs(z_1 - 1) + 1)))
        elif self.nac_mul == 'max-safe':
            z_2 = torch.exp(self.layer_2(torch.log(torch.relu(z_1 - 1) + 1)))
        else:
            raise ValueError(f'Unsupported nac_mul option ({self.nac_mul})')

        self.writer.add_summary('z_2', z_2)
        if self.actor:
            z_2 = F.softmax(z_2, dim=-1)
        return z_2

    def extra_repr(self):
        return 'unit_name={}, input_size={}'.format(
            self.unit_name, self.input_size
        )
    
    def predict(self, x):
        return self(x).detach().numpy().flatten()
    
    def select_action(self, x):
        return torch.multinomial(self(x), 1).detach().numpy().flatten()

# %%
NetworkNAU.UNIT_NAMES
# Out:
# {'ELU',
#  'GradientBanditNAC',
#  'GradientBanditNALU',
#  'GumbelMNAC',
#  'GumbelNAC',
#  'GumbelNALU',
#  'HardSoftmaxNAC',
#  'HardSoftmaxNALU',
#  'IndependentNAC',
#  'IndependentNALU',
#  'LinearNAC',
#  'LinearNALU',
#  'MNAC',
#  'NAC',
#  'NALU',
#  'PosNAC',
#  'PosNALU',
#  'ReLU',
#  'ReLU6',
#  'ReRegualizedLinearMNAC',
#  'ReRegualizedLinearNAC',
#  'ReRegualizedLinearNALU',
#  'ReRegualizedLinearPosNAC',
#  'RegualizedLinearMNAC',
#  'RegualizedLinearNAC',
#  'RegualizedLinearNALU',
#  'SELU',
#  'Sigmoid',
#  'SillyReRegualizedLinearMNAC',
#  'SillyReRegualizedLinearNAC',
#  'SillyReRegualizedLinearNALU',
#  'SoftmaxNAC',
#  'SoftmaxNALU',
#  'Softsign',
#  'Tanh',
#  'linear'}

# %%
net = NetworkNAU('ReRegualizedLinearMNAC', input_size=5, hidden_size=16, output_size=1)

# %%
net = NetworkNAU('ReRegualizedLinearMNAC', input_size=5, hidden_size=16, output_size=2)

# %%
net = NetworkNAURNN('ReRegualizedLinearMNAC', input_size=5, hidden_size=16, output_size=1)

# %% [markdown]
# ### Training

# %%
env_id = 'CartPole-v1'
value_learning_rate = 0.001
actor_learning_rate = 0.001
gamma = 0.99
entropy = 1
seed = 1

config_a2c = {
    'env_id': env_id,
    'gamma': gamma,
    'seed': seed,
    'value_network': {'learning_rate': value_learning_rate},
    'actor_network': {'learning_rate': actor_learning_rate},
    'entropy': entropy
}

print("Current config_a2c is:")
pprint(config_a2c)
# Out:
# Current config_a2c is:
# {'actor_network': {'learning_rate': 0.001},
#  'entropy': 1,
#  'env_id': 'CartPole-v1',
#  'gamma': 0.99,
#  'seed': 1,
#  'value_network': {'learning_rate': 0.001}}

# %%
# a_net = NetworkNAU('NALU', input_size=5, hidden_size=128, output_size=agent.env.action_space.n, actor=True)
a_net = ActorNetworkNAU(agent.env.observation_space.shape[0] + 1, 16, agent.env.action_space.n)
v_net = NetworkNAU('ReRegualizedLinearMNAC', input_size=5, hidden_size=64, output_size=1)

# %%
agent = A2CAgentRNN(config_a2c, range_train=(0.05, 0.2), range_eval=(0.05, 0.2),
                    a_net=a_net, v_net=v_net, LSTM=False, reg=0.1)

# %%
rewards = agent.training_batch(1000, 256)
# Out:
# Epoch 0/1000: Mean rewards: 21.72, Std: 12.54
# Epoch 50/1000: Mean rewards: 32.28, Std: 16.95
# Epoch 100/1000: Mean rewards: 48.88, Std: 28.36
# Epoch 150/1000: Mean rewards: 98.26, Std: 49.82
# Epoch 200/1000: Mean rewards: 139.62, Std: 71.55
# Epoch 250/1000: Mean rewards: 157.44, Std: 81.49
# Epoch 300/1000: Mean rewards: 218.34, Std: 83.74
# Epoch 350/1000: Mean rewards: 266.08, Std: 106.87
# Epoch 400/1000: Mean rewards: 292.92, Std: 117.96
# Epoch 450/1000: Mean rewards: 334.5, Std: 116.38
# Epoch 500/1000: Mean rewards: 307.24, Std: 106.87
# Epoch 550/1000: Mean rewards: 211.1, Std: 57.7
# Epoch 600/1000: Mean rewards: 393.04, Std: 131.29
# Epoch 650/1000: Mean rewards: 364.88, Std: 121.47
# Epoch 700/1000: Mean rewards: 396.48, Std: 134.11
# Epoch 750/1000: Mean rewards: 399.28, Std: 105.54
# Epoch 800/1000: Mean rewards: 463.12, Std: 74.08
# Epoch 850/1000: Mean rewards: 429.66, Std: 113.66
# Epoch 900/1000: Mean rewards: 452.72, Std: 90.91
# Epoch 950/1000: Mean rewards: 450.7, Std: 89.65
# Epoch 999/1000: Mean rewards: 404.28, Std: 104.87
# <img src="data:image/png;base64,..." width="639.9999861283738">
# The training was done over a total of 1756 episodes

# %% [markdown]
# ### Evaluation

# %%
eval_agent(agent, 100, 0.05, 0.2)
# Out:
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# Mean success : 432.32 +- 89.42

# %%
eval_agent(agent, 100, 0.2, 0.5)
# Out:
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# Mean success : 463.74 +- 94.31

# %%
eval_agent(agent, 100, 0.2, 1)
# Out:
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# Mean success : 424.26 +- 108.26

# %%
eval_agent(agent, 100, 0.5, 2)
# Out:
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# Mean success : 148.25 +- 176.85

# %%
eval_agent(agent, 100, 1, 5)
# Out:
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# Mean success : 22.91 +- 43.44

# %% [markdown]
# ## NAU

# %%
layer_name = 'ReRegualizedLinearMNAC'
# layer_name = 'NAC'
class ValueNetworkNAU(nn.Module):

    def __init__(self, input_size, hidden_size, output_size):
        super(ValueNetworkNAU, self).__init__()
        self.fc1 = stable_nalu.layer.GeneralizedLayer(input_size, hidden_size, layer_name)
        self.fc2 = stable_nalu.layer.GeneralizedLayer(hidden_size, hidden_size, layer_name)
        self.fc22 = stable_nalu.layer.GeneralizedLayer(hidden_size, hidden_size*2, layer_name)
        self.fc23 = stable_nalu.layer.GeneralizedLayer(hidden_size*2, hidden_size, layer_name)
        self.fc3 = stable_nalu.layer.GeneralizedLayer(hidden_size, output_size, layer_name)
    
        self.fc1.reset_parameters()
        self.fc2.reset_parameters()
        self.fc22.reset_parameters()
        self.fc23.reset_parameters()
        self.fc3.reset_parameters()

    def forward(self, x):
        if len(x.size()) == 1:
            x = x[None]
        out = self.fc1(x)
        out = self.fc2(out)
        out = self.fc22(out)
        out = self.fc23(out)
        out = self.fc3(out)
        return out
    
    def predict(self, x):
        return self(x).detach().numpy()[0]

# %%
v = ValueNetworkNAU(5, 16, 1)
v(torch.rand(10, 5))
# Out:
# tensor([[3.2908e-05],
#         [3.2908e-05],
#         [3.2908e-05],
#         [3.2908e-05],
#         [3.2908e-05],
#         [3.2908e-05],
#         [3.2908e-05],
#         [3.2908e-05],
#         [3.2908e-05],
#         [3.2908e-05]], grad_fn=<ProdBackward1>)

# %%
layer_name = 'NAC'
class ActorNetworkNAU(nn.Module):

    def __init__(self, input_size, hidden_size, action_size):
        super(ActorNetworkNAU, self).__init__()
        self.fc1 = nn.Linear(input_size, hidden_size)
        self.fc2 = nn.Linear(hidden_size, hidden_size)
        self.fc3 = nn.Linear(hidden_size, action_size)

    def forward(self, x):
        out = F.relu(self.fc1(x))
        out = F.relu(self.fc2(out))
        out = F.softmax(self.fc3(out), dim=-1)
        return out
    
    def select_action(self, x):
        return torch.multinomial(self(x), 1).detach().numpy()

# %%
env_id = 'CartPole-v1'
value_learning_rate = 0.001
actor_learning_rate = 0.001
gamma = 0.99
entropy = 1
seed = 1

config_a2c = {
    'env_id': env_id,
    'gamma': gamma,
    'seed': seed,
    'value_network': {'learning_rate': value_learning_rate},
    'actor_network': {'learning_rate': actor_learning_rate},
    'entropy': entropy
}

print("Current config_a2c is:")
pprint(config_a2c)
# Out:
# Current config_a2c is:
# {'actor_network': {'learning_rate': 0.001},
#  'entropy': 1,
#  'env_id': 'CartPole-v1',
#  'gamma': 0.99,
#  'seed': 1,
#  'value_network': {'learning_rate': 0.001}}

# %%
agent = A2CAgentRandom(config_a2c, range_train=(0.1, 0.1), range_eval=(0.1, 0.1))

# %%
agent.actor_network = ActorNetworkNAU(agent.env.observation_space.shape[0] + 1, 16, agent.env.action_space.n)
agent.value_network = ValueNetworkNAU(agent.env.observation_space.shape[0] + 1, 16, 1)
agent.value_network_optimizer = optim.RMSprop(agent.value_network.parameters(), lr=config_a2c['value_network']['learning_rate'])
agent.actor_network_optimizer = optim.RMSprop(agent.actor_network.parameters(), lr=config_a2c['actor_network']['learning_rate'])

# %%
rewards = agent.training_batch(1000, 256)
# Out:
# Epoch 0/1000: Mean rewards: 28.32, Std: 17.21
# Epoch 50/1000: Mean rewards: 52.84, Std: 22.66
# Epoch 100/1000: Mean rewards: 58.24, Std: 23.01
# Epoch 150/1000: Mean rewards: 64.0, Std: 25.52
# Epoch 200/1000: Mean rewards: 141.62, Std: 55.89
# Epoch 250/1000: Mean rewards: 187.24, Std: 79.88
# Epoch 300/1000: Mean rewards: 255.06, Std: 111.05
# Epoch 350/1000: Mean rewards: 319.6, Std: 134.14
# Epoch 400/1000: Mean rewards: 348.1, Std: 137.57
# Epoch 450/1000: Mean rewards: 295.14, Std: 94.32
# Epoch 500/1000: Mean rewards: 343.08, Std: 107.66
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-251-aa60c66b99c7> in <module>
# ----> 1 rewards = agent.training_batch(1000, 256)
#
# ~\Documents\Cours_3A\Object_recognition_and_CV\Project\RLfunctions.py in training_batch(self, epochs, batch_size)
#     317                 observations[i] = observation
#     318                 actions[i] = self.actor_network.select_action(torch.tensor(observations[i] , dtype=torch.float))
# --> 319                 values[i] = self.value_network.predict(torch.tensor(observations[i] , dtype=torch.float))
#     320                 # step
#     321                 observation, reward, done, _ = self.env.step(actions[i])
#
# <ipython-input-247-07d5cfd87629> in predict(self, x)
#      28
#      29     def predict(self, x):
# ---> 30         return self(x).detach().numpy()[0]
#
# c:\tools\anaconda3\envs\orcv\lib\site-packages\torch\nn\modules\module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# <ipython-input-247-07d5cfd87629> in forward(self, x)
#      23         out = self.fc2(out)
#      24         out = self.fc22(out)
# ---> 25         out = self.fc23(out)
#      26         out = self.fc3(out)
#      27         return out
#
# c:\tools\anaconda3\envs\orcv\lib\site-packages\torch\nn\modules\module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# c:\users\maxime\documents\cours_3a\object_recognition_and_cv\project\stable-nalu\stable_nalu\layer\generalized.py in forward(self, input)
#     151
#     152     def forward(self, input):
# --> 153         return self.layer(input)
#     154
#     155     def extra_repr(self):
#
# c:\tools\anaconda3\envs\orcv\lib\site-packages\torch\nn\modules\module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# c:\users\maxime\documents\cours_3a\object_recognition_and_cv\project\stable-nalu\stable_nalu\layer\re_regualized_linear_mnac.py in forward(self, x, reuse)
#      83             out = z_normalized * (c ** torch.sum(W, 1))
#      84         else:
# ---> 85             out = mnac(x, W, mode='prod')
#      86         return out
#      87
#
# c:\users\maxime\documents\cours_3a\object_recognition_and_cv\project\stable-nalu\stable_nalu\functional\mnac.py in mnac(x, W, mode)
#       8
#       9     if mode == 'prod':
# ---> 10         return torch.prod(x * W + 1 - W, -2)
#      11     elif mode == 'exp-log':
#      12         return torch.exp(torch.sum(torch.log(x * W + 1 - W), -2))
#
# KeyboardInterrupt:

# %% [markdown]
# # Cleaner

# %%
env_id = 'CartPole-v1'
value_learning_rate = 0.001
actor_learning_rate = 0.001
gamma = 0.99
entropy = 1
seed = 1

config_a2c = {
    'env_id': env_id,
    'gamma': gamma,
    'seed': seed,
    'value_network': {'learning_rate': value_learning_rate},
    'actor_network': {'learning_rate': actor_learning_rate},
    'entropy': entropy
}

print("Current config_a2c is:")
pprint(config_a2c)
# Out:
# Current config_a2c is:
# {'actor_network': {'learning_rate': 0.001},
#  'entropy': 1,
#  'env_id': 'CartPole-v1',
#  'gamma': 0.99,
#  'seed': 1,
#  'value_network': {'learning_rate': 0.001}}

# %%
# hidden_size = 32
hidden_size = [32, 32]
# hidden_size = [32, 32, 32]
range_train = (0.05, 0.2)

# %% [markdown]
# ### Baseline

# %%
# agents = []
# name_agents = ['baseline']

# %%
a_net = ActorNetwork(5, hidden_size, 2)
v_net = ValueNetwork(5, hidden_size, 1)

# %%
agent = A2CAgentRNN(config_a2c, range_train=range_train, range_eval=range_train,
                    a_net=a_net, v_net=v_net, LSTM=False, reg=0.1)
agent.training_batch(1000, 256, disp=False);

# %%
agents.append(agent)

# %% [markdown]
# ## NAU

# %% [markdown]
# ### Test

# %%
NetworkNAU.UNIT_NAMES
# Out:
# {'ELU',
#  'GradientBanditNAC',
#  'GradientBanditNALU',
#  'GumbelMNAC',
#  'GumbelNAC',
#  'GumbelNALU',
#  'HardSoftmaxNAC',
#  'HardSoftmaxNALU',
#  'IndependentNAC',
#  'IndependentNALU',
#  'LinearNAC',
#  'LinearNALU',
#  'MNAC',
#  'NAC',
#  'NALU',
#  'PosNAC',
#  'PosNALU',
#  'ReLU',
#  'ReLU6',
#  'ReRegualizedLinearMNAC',
#  'ReRegualizedLinearNAC',
#  'ReRegualizedLinearNALU',
#  'ReRegualizedLinearPosNAC',
#  'RegualizedLinearMNAC',
#  'RegualizedLinearNAC',
#  'RegualizedLinearNALU',
#  'SELU',
#  'Sigmoid',
#  'SillyReRegualizedLinearMNAC',
#  'SillyReRegualizedLinearNAC',
#  'SillyReRegualizedLinearNALU',
#  'SoftmaxNAC',
#  'SoftmaxNALU',
#  'Softsign',
#  'Tanh',
#  'linear'}

# %%
a_net = NetworkNAU('ReRegualizedLinearNAC', 5, hidden_size=hidden_size, output_size=2, actor=True)
v_net = NetworkNAU('ReRegualizedLinearNAC', 5, hidden_size=hidden_size, output_size=1)
agent = A2CAgentRNN(config_a2c, range_train=range_train, range_eval=range_train,
                    a_net=a_net, v_net=v_net, LSTM=False, reg=1)
agent.training_batch(1000, 256, disp=True)
# Out:
# Epoch 0/1000: Mean rewards: 16.68, Std: 7.74
# Epoch 20/1000: Mean rewards: 240.02, Std: 92.64
# Epoch 40/1000: Mean rewards: 400.02, Std: 110.0
# Epoch 60/1000: Mean rewards: 246.98, Std: 71.69
# Epoch 80/1000: Mean rewards: 384.1, Std: 91.48
# Epoch 100/1000: Mean rewards: 382.3, Std: 89.16
# Epoch 120/1000: Mean rewards: 392.84, Std: 107.1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-1b3edd3ebc1d> in <module>
#       3 agent = A2CAgentRNN(config_a2c, range_train=range_train, range_eval=range_train,
#       4                     a_net=a_net, v_net=v_net, LSTM=False, reg=1)
# ----> 5 agent.training_batch(1000, 256, disp=True)
#
# ~\Documents\Cours_3A\Object_recognition_and_CV\Project\NAU_RL.py in training_batch(self, epochs, batch_size, disp, gpu)
#     353             # Test it every 50 epochs
#     354             if epoch % 20 == 0 or epoch == epochs - 1:
# --> 355                 rewards_test.append(np.array([self.evaluate(*self.range_eval) for _ in range(50)]))
#     356                 if disp: print(f'Epoch {epoch}/{epochs}: Mean rewards: {round(rewards_test[-1].mean(), 2)}, Std: {round(rewards_test[-1].std(), 2)}')
#     357
#
# ~\Documents\Cours_3A\Object_recognition_and_CV\Project\NAU_RL.py in <listcomp>(.0)
#     353             # Test it every 50 epochs
#     354             if epoch % 20 == 0 or epoch == epochs - 1:
# --> 355                 rewards_test.append(np.array([self.evaluate(*self.range_eval) for _ in range(50)]))
#     356                 if disp: print(f'Epoch {epoch}/{epochs}: Mean rewards: {round(rewards_test[-1].mean(), 2)}, Std: {round(rewards_test[-1].std(), 2)}')
#     357
#
# ~\Documents\Cours_3A\Object_recognition_and_CV\Project\RLfunctions.py in evaluate(self, min_mass, max_mass, render)
#     411                 if move_to_gpu:
#     412                     observation = observation.cuda()
# --> 413                 policy = self.actor_network(observation)
#     414                 action = torch.multinomial(policy, 1)
#     415                 observation, reward, done, info = env.step(int(action))
#
# C:\tools\Anaconda3\lib\site-packages\torch\nn\modules\module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# ~\Documents\Cours_3A\Object_recognition_and_CV\Project\NAU_RL.py in forward(self, input)
#     203         if hasattr(self.hidden_size, '__iter__'):
#     204             for l in self.layers:
# --> 205                 input = l(input)
#     206             z_2 = input
#     207         else:
#
# C:\tools\Anaconda3\lib\site-packages\torch\nn\modules\module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# c:\users\maxime\documents\cours_3a\object_recognition_and_cv\project\stable-nalu\stable_nalu\layer\generalized.py in forward(self, input)
#     151
#     152     def forward(self, input):
# --> 153         return self.layer(input)
#     154
#     155     def extra_repr(self):
#
# C:\tools\Anaconda3\lib\site-packages\torch\nn\modules\module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# c:\users\maxime\documents\cours_3a\object_recognition_and_cv\project\stable-nalu\stable_nalu\layer\basic.py in forward(self, input, reuse)
#      76         self.writer.add_histogram('W', self.W)
#      77         self.writer.add_tensor('W', self.W)
# ---> 78         self.writer.add_scalar('W/sparsity_error', sparsity_error(self.W), verbose_only=False)
#      79         return self.activation_fn(
#      80             torch.nn.functional.linear(input, self.W, self.bias)
#
# c:\users\maxime\documents\cours_3a\object_recognition_and_cv\project\stable-nalu\stable_nalu\functional\sparsity_error.py in sparsity_error(W)
#       3
#       4 def sparsity_error(W):
# ----> 5     W_error = torch.min(torch.abs(W), torch.abs(1 - torch.abs(W)))
#       6     return torch.max(W_error)
#
# KeyboardInterrupt:

# %%
agent.evaluate(1, 1, render=True)
# Out:
# <video alt="gym-results\openaigym.video.16.1764.video000000.mp4" autoplay
#                       loop controls style="height: 400px;">
#                       <source src="data:video/mp4;base64,..." type="video/mp4" />
#                  </video>
# Reward: 153.0
# masspole : 1.00
# 153.0

# %%
eval_agent(agent, 100, 2, 3, disp=True)
# Out:
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# Mean success : 8.51 +- 1.41
# array([10., 10.,  7.,  7.,  7.,  9., 10., 10., 11.,  9.,  9.,  8.,  8.,
#         8., 10.,  9.,  9.,  8.,  7.,  7.,  8.,  9., 12.,  9.,  7., 10.,
#         9.,  6., 10.,  9.,  7., 10.,  9.,  8.,  8.,  8.,  9.,  9.,  7.,
#         8.,  7.,  9.,  7.,  9., 14.,  9.,  8.,  9., 12.,  8., 10.,  7.,
#         8.,  8.,  9.,  9.,  7.,  7.,  8.,  9.,  8., 11.,  8.,  9.,  9.,
#         9.,  9.,  7., 10.,  9.,  9., 10.,  8.,  7.,  9., 11.,  9.,  8.,
#         9.,  9.,  8.,  9.,  7.,  7.,  9., 12.,  8.,  7.,  7.,  8.,  7.,
#         9.,  8.,  7.,  7.,  8.,  6.,  8.,  6.,  6.])

# %% [markdown]
# ### Only critic

# %%
NetworkNAU.UNIT_NAMES
# Out:
# {'ELU',
#  'GradientBanditNAC',
#  'GradientBanditNALU',
#  'GumbelMNAC',
#  'GumbelNAC',
#  'GumbelNALU',
#  'HardSoftmaxNAC',
#  'HardSoftmaxNALU',
#  'IndependentNAC',
#  'IndependentNALU',
#  'LinearNAC',
#  'LinearNALU',
#  'MNAC',
#  'NAC',
#  'NALU',
#  'PosNAC',
#  'PosNALU',
#  'ReLU',
#  'ReLU6',
#  'ReRegualizedLinearMNAC',
#  'ReRegualizedLinearNAC',
#  'ReRegualizedLinearNALU',
#  'ReRegualizedLinearPosNAC',
#  'RegualizedLinearMNAC',
#  'RegualizedLinearNAC',
#  'RegualizedLinearNALU',
#  'SELU',
#  'Sigmoid',
#  'SillyReRegualizedLinearMNAC',
#  'SillyReRegualizedLinearNAC',
#  'SillyReRegualizedLinearNALU',
#  'SoftmaxNAC',
#  'SoftmaxNALU',
#  'Softsign',
#  'Tanh',
#  'linear'}

# %%
agents = []
name_agents = []

# %%
# %%time
for unit_name in ['ReLU', 'MNAC', 'NAC', 'NALU', 'ReRegualizedLinearMNAC', 'ReRegualizedLinearNAC']:
    a_net = NetworkNAU('ReLU', input_size=5, hidden_size=hidden_size, output_size=2, actor=True)
    v_net = NetworkNAU(unit_name, input_size=5, hidden_size=hidden_size, output_size=1)
    agent = A2CAgentRNN(config_a2c, range_train=range_train, range_eval=range_train,
                        a_net=a_net, v_net=v_net, LSTM=False, reg=1)
    agent.training_batch(1000, 256, disp=False)
    print(unit_name)
    eval_agent(agent, 100, range_train[0], range_train[1], disp=True)
    agents.append(agent)
    name_agents.append(unit_name)
    print('')
# Out:
# ReLU
# Mean success : 482.21 +- 54.73
#
# MNAC
# Mean success : 467.69 +- 71.86
#
# NAC
# Mean success : 466.85 +- 78.26
#
# NALU
# Mean success : 485.93 +- 58.34
#
# ReRegualizedLinearMNAC
# Mean success : 470.69 +- 70.93
#
# ReRegualizedLinearNAC
# Mean success : 480.50 +- 55.79
#
# Wall time: 50min 16s

# %% [markdown]
# #### Evaluation

# %%
masses = np.geomspace(0.2, 2, num=21)
min_mass = masses[:-1]
max_mass = masses[1:]
n_eval = 100
print(max_mass)
rewards = np.zeros((len(agents), len(max_mass), n_eval))
pbar = tqdm.notebook.tqdm(total=len(max_mass) * len(agents))
for j, m in enumerate(max_mass):
    for i, a in enumerate(agents):
        rws = eval_agent(a, n_eval, min_mass[i], m)
        rewards[i, j] = rws
        pbar.update(1)
pbar.close()
# Out:
# [0.22440369 0.25178508 0.28250751 0.31697864 0.35565588 0.39905246
#  0.44774423 0.50237729 0.56367659 0.63245553 0.70962678 0.79621434
#  0.89336718 1.00237447 1.12468265 1.26191469 1.41589157 1.58865647
#  1.78250188 2.        ]
# HBox(children=(IntProgress(value=0, max=120), HTML(value='')))

# %%
np.save('../figures/rewards_only_critic', rewards)

# %%
name_agents = ['ReLU', 'MNAC', 'NAC', 'NALU', 'ReRegualizedLinearMNAC', 'ReRegualizedLinearNAC']

# %%
rewards.shape
# Out:
# (6, 20, 100)

# %%
df = []
for i, agent in enumerate(name_agents):
    for j, mass in enumerate(max_mass):
        for k, it in enumerate(list(range(n_eval))):
            df.append([agent, mass, it, rewards[i, j, k]])
df = pd.DataFrame(df, columns=['model', 'mass', 'iter', 'value'])

# %%
fig, ax = plt.subplots(figsize=(8, 5))
ax.set_xscale('log')
sns.lineplot(data=df, x='mass', y='value', hue='model', ax=ax)
# Out:
# <img src="data:image/png;base64,..." width="799.9999826604674">

# %%
fig, ax = plt.subplots(figsize=(8, 5))
for i in range(6):
    if i == 0:
        ax.errorbar(max_mass, rewards[i].mean(axis=1)/500, yerr=rewards[i].std(axis=1)/500,
                     barsabove=True, capsize=5, label=name_agents[i], color='black', linewidth=5, elinewidth=1)
    else:
        ax.errorbar(max_mass, rewards[i].mean(axis=1)/500, yerr=rewards[i].std(axis=1)/500,
                     barsabove=True, capsize=5, label=name_agents[i], linewidth=3, elinewidth=1)
ax = fig.axes[0]
ax.legend()
# ax.set_xlim(0.05, max_mass[-1])
ax.set_xscale('log')
# ax.set_ylim(0, 1)
# ax.set_yscale('log')
ax.set_ylabel('Reward')
ax.set_xlabel('Max mass')
plt.savefig('../figures/layer_type_value.pdf', format='pdf')
# Out:
# <img src="data:image/png;base64,..." width="799.9999826604674">

# %% [markdown]
# ### Only actor

# %%
# NetworkNAU.UNIT_NAMES

# %%
name_agents = ['ReLU', 'MNAC', 'NAC', 'NALU', 'ReRegualizedLinearMNAC', 'ReRegualizedLinearNAC']
agents = []

# %%
# %%time
for unit_name in name_agents:
    a_net = NetworkNAU(unit_name, input_size=5, hidden_size=hidden_size, output_size=2, actor=True)
    v_net = NetworkNAU('ReLU', input_size=5, hidden_size=hidden_size, output_size=1)
    agent = A2CAgentRNN(config_a2c, range_train=range_train, range_eval=range_train,
                        a_net=a_net, v_net=v_net, LSTM=False, reg=1)
    agent.training_batch(1000, 256, disp=True)
    print(unit_name)
    eval_agent(agent, 100, range_train[0], range_train[1], disp=True)
    agents.append(agent)
    print('')
# Out:
# Epoch 0/1000: Mean rewards: 20.92, Std: 11.51
# Epoch 20/1000: Mean rewards: 100.86, Std: 64.76
# Epoch 40/1000: Mean rewards: 187.84, Std: 81.37
# Epoch 60/1000: Mean rewards: 193.7, Std: 66.42
# Epoch 80/1000: Mean rewards: 217.66, Std: 77.17
# Epoch 100/1000: Mean rewards: 215.52, Std: 74.77
# Epoch 120/1000: Mean rewards: 244.34, Std: 72.15
# Epoch 140/1000: Mean rewards: 326.04, Std: 117.99
# Epoch 160/1000: Mean rewards: 280.46, Std: 96.21
# Epoch 180/1000: Mean rewards: 407.6, Std: 93.0
# Epoch 200/1000: Mean rewards: 367.86, Std: 111.94
# Epoch 220/1000: Mean rewards: 335.66, Std: 144.07
# Epoch 240/1000: Mean rewards: 376.48, Std: 118.97
# Epoch 260/1000: Mean rewards: 319.26, Std: 98.27
# Epoch 280/1000: Mean rewards: 369.02, Std: 111.89
# Epoch 300/1000: Mean rewards: 270.8, Std: 86.01
# Epoch 320/1000: Mean rewards: 289.3, Std: 88.28
# Epoch 340/1000: Mean rewards: 337.3, Std: 101.65
# Epoch 360/1000: Mean rewards: 263.0, Std: 89.23
# Epoch 380/1000: Mean rewards: 333.24, Std: 110.21
# Epoch 400/1000: Mean rewards: 327.28, Std: 101.04
# Epoch 420/1000: Mean rewards: 257.7, Std: 79.63
# Epoch 440/1000: Mean rewards: 331.56, Std: 102.74
# Epoch 460/1000: Mean rewards: 366.06, Std: 102.58
# Epoch 480/1000: Mean rewards: 302.92, Std: 84.97
# Epoch 500/1000: Mean rewards: 375.06, Std: 114.31
# Epoch 520/1000: Mean rewards: 420.7, Std: 92.41
# Epoch 540/1000: Mean rewards: 376.26, Std: 104.65
# Epoch 560/1000: Mean rewards: 304.58, Std: 90.08
# Epoch 580/1000: Mean rewards: 438.68, Std: 89.1
# Epoch 600/1000: Mean rewards: 428.64, Std: 92.75
# Epoch 620/1000: Mean rewards: 455.68, Std: 76.76
# Epoch 640/1000: Mean rewards: 438.88, Std: 98.95
# Epoch 660/1000: Mean rewards: 415.08, Std: 129.42
# Epoch 680/1000: Mean rewards: 442.64, Std: 93.79
# Epoch 700/1000: Mean rewards: 459.26, Std: 91.13
# Epoch 720/1000: Mean rewards: 449.8, Std: 98.75
# Epoch 740/1000: Mean rewards: 424.28, Std: 100.6
# Epoch 760/1000: Mean rewards: 457.52, Std: 89.98
# Epoch 780/1000: Mean rewards: 432.96, Std: 106.98
# Epoch 800/1000: Mean rewards: 443.72, Std: 73.84
# Epoch 820/1000: Mean rewards: 453.36, Std: 83.54
# Epoch 840/1000: Mean rewards: 421.1, Std: 107.77
# Epoch 860/1000: Mean rewards: 439.68, Std: 96.63
# Epoch 880/1000: Mean rewards: 469.28, Std: 65.89
# Epoch 900/1000: Mean rewards: 385.5, Std: 120.1
# Epoch 920/1000: Mean rewards: 369.46, Std: 111.16
# Epoch 940/1000: Mean rewards: 272.36, Std: 98.53
# Epoch 960/1000: Mean rewards: 462.44, Std: 88.99
# Epoch 980/1000: Mean rewards: 491.68, Std: 36.07
# Early stopping !
# <img src="data:image/png;base64,..." width="639.9999861283738">
# The training was done over a total of 851 episodes
# ReLU
# Mean success : 477.77 +- 63.65
#
# Epoch 0/1000: Mean rewards: 21.9, Std: 12.03
# Epoch 20/1000: Mean rewards: 23.02, Std: 13.3
# Epoch 40/1000: Mean rewards: 22.68, Std: 11.65
# Epoch 60/1000: Mean rewards: 23.12, Std: 14.35
# Epoch 80/1000: Mean rewards: 22.68, Std: 15.5
# Epoch 100/1000: Mean rewards: 21.32, Std: 9.58
# Epoch 120/1000: Mean rewards: 23.58, Std: 12.72
# Epoch 140/1000: Mean rewards: 20.94, Std: 12.97
# Epoch 160/1000: Mean rewards: 25.04, Std: 12.98
# Epoch 180/1000: Mean rewards: 23.1, Std: 10.36
# Epoch 200/1000: Mean rewards: 22.88, Std: 11.34
# Epoch 220/1000: Mean rewards: 24.0, Std: 13.49
# Epoch 240/1000: Mean rewards: 23.4, Std: 12.44
# Epoch 260/1000: Mean rewards: 20.58, Std: 8.52
# Epoch 280/1000: Mean rewards: 22.64, Std: 12.25
# Epoch 300/1000: Mean rewards: 21.8, Std: 12.61
# Epoch 320/1000: Mean rewards: 23.16, Std: 11.71
# Epoch 340/1000: Mean rewards: 22.96, Std: 13.34
# Epoch 360/1000: Mean rewards: 21.88, Std: 10.89
# Epoch 380/1000: Mean rewards: 22.64, Std: 11.73
# Epoch 400/1000: Mean rewards: 23.4, Std: 11.7
# Epoch 420/1000: Mean rewards: 23.28, Std: 12.74
# Epoch 440/1000: Mean rewards: 23.94, Std: 14.94
# Epoch 460/1000: Mean rewards: 24.74, Std: 14.16
# Epoch 480/1000: Mean rewards: 20.5, Std: 10.52
# Epoch 500/1000: Mean rewards: 25.28, Std: 16.55
# Epoch 520/1000: Mean rewards: 20.66, Std: 12.65
# Epoch 540/1000: Mean rewards: 20.76, Std: 11.9
# Epoch 560/1000: Mean rewards: 22.84, Std: 11.01
# Epoch 580/1000: Mean rewards: 24.38, Std: 17.44
# Epoch 600/1000: Mean rewards: 23.3, Std: 11.51
# Epoch 620/1000: Mean rewards: 19.42, Std: 8.92
# Epoch 640/1000: Mean rewards: 23.32, Std: 13.12
# Epoch 660/1000: Mean rewards: 23.2, Std: 11.94
# Epoch 680/1000: Mean rewards: 20.62, Std: 11.92
# Epoch 700/1000: Mean rewards: 22.84, Std: 13.34
# Epoch 720/1000: Mean rewards: 21.5, Std: 11.33
# Epoch 740/1000: Mean rewards: 22.86, Std: 14.85
# Epoch 760/1000: Mean rewards: 22.06, Std: 13.9
# Epoch 780/1000: Mean rewards: 19.5, Std: 8.27
# Epoch 800/1000: Mean rewards: 23.34, Std: 15.83
# Epoch 820/1000: Mean rewards: 25.88, Std: 12.59
# Epoch 840/1000: Mean rewards: 24.06, Std: 14.79
# Epoch 860/1000: Mean rewards: 22.3, Std: 11.53
# Epoch 880/1000: Mean rewards: 22.62, Std: 13.94
# Epoch 900/1000: Mean rewards: 23.86, Std: 13.33
# Epoch 920/1000: Mean rewards: 21.32, Std: 10.81
# Epoch 940/1000: Mean rewards: 22.98, Std: 11.06
# Epoch 960/1000: Mean rewards: 22.66, Std: 12.66
# Epoch 980/1000: Mean rewards: 22.68, Std: 12.38
# Epoch 999/1000: Mean rewards: 23.16, Std: 14.6
# <img src="data:image/png;base64,..." width="639.9999861283738">
# The training was done over a total of 11633 episodes
# MNAC
# Mean success : 21.57 +- 12.24
#
# Epoch 0/1000: Mean rewards: 43.34, Std: 27.41
# Epoch 20/1000: Mean rewards: 121.7, Std: 73.79
# Epoch 40/1000: Mean rewards: 180.0, Std: 88.38
# Epoch 60/1000: Mean rewards: 275.98, Std: 128.48
# Epoch 80/1000: Mean rewards: 310.08, Std: 127.34
# Epoch 100/1000: Mean rewards: 334.48, Std: 123.68
# Epoch 120/1000: Mean rewards: 304.04, Std: 128.57
# Epoch 140/1000: Mean rewards: 374.6, Std: 129.58
# Epoch 160/1000: Mean rewards: 365.56, Std: 123.36
# Epoch 180/1000: Mean rewards: 382.3, Std: 118.21
# Epoch 200/1000: Mean rewards: 386.72, Std: 112.93
# Epoch 220/1000: Mean rewards: 403.2, Std: 102.84
# Epoch 240/1000: Mean rewards: 443.94, Std: 104.14
# Epoch 260/1000: Mean rewards: 426.56, Std: 106.65
# Epoch 280/1000: Mean rewards: 363.74, Std: 115.07
# Epoch 300/1000: Mean rewards: 448.08, Std: 111.74
# Epoch 320/1000: Mean rewards: 404.52, Std: 126.97
# Epoch 340/1000: Mean rewards: 426.08, Std: 105.09
# Epoch 360/1000: Mean rewards: 393.86, Std: 122.83
# Epoch 380/1000: Mean rewards: 407.16, Std: 127.86
# Epoch 400/1000: Mean rewards: 363.74, Std: 125.06
# Epoch 420/1000: Mean rewards: 428.8, Std: 103.05
# Epoch 440/1000: Mean rewards: 455.76, Std: 90.66
# Epoch 460/1000: Mean rewards: 467.88, Std: 76.27
# Epoch 480/1000: Mean rewards: 487.68, Std: 39.79
# Epoch 500/1000: Mean rewards: 489.4, Std: 49.04
# Epoch 520/1000: Mean rewards: 457.94, Std: 97.87
# Epoch 540/1000: Mean rewards: 475.34, Std: 62.28
# Epoch 560/1000: Mean rewards: 482.98, Std: 58.17
# Epoch 580/1000: Mean rewards: 392.34, Std: 114.59
# Epoch 600/1000: Mean rewards: 376.52, Std: 119.62
# Epoch 620/1000: Mean rewards: 477.08, Std: 61.09
# Epoch 640/1000: Mean rewards: 487.8, Std: 42.78
# Epoch 660/1000: Mean rewards: 463.54, Std: 92.1
# Epoch 680/1000: Mean rewards: 474.2, Std: 79.87
# Epoch 700/1000: Mean rewards: 453.98, Std: 86.27
# Epoch 720/1000: Mean rewards: 457.18, Std: 103.53
# Epoch 740/1000: Mean rewards: 489.42, Std: 46.5
# Epoch 760/1000: Mean rewards: 499.12, Std: 6.16
# Early stopping !
# <img src="data:image/png;base64,..." width="639.9999861283738">
# The training was done over a total of 547 episodes
# NAC
# Mean success : 490.61 +- 48.45
#
# Epoch 0/1000: Mean rewards: 10.78, Std: 1.77
# Epoch 20/1000: Mean rewards: 26.18, Std: 9.32
# Epoch 40/1000: Mean rewards: 28.94, Std: 10.87
# Epoch 60/1000: Mean rewards: 34.28, Std: 11.17
# Epoch 80/1000: Mean rewards: 39.08, Std: 14.04
# Epoch 100/1000: Mean rewards: 40.1, Std: 23.67
# Epoch 120/1000: Mean rewards: 46.28, Std: 21.46
# Epoch 140/1000: Mean rewards: 40.8, Std: 16.57
# Epoch 160/1000: Mean rewards: 42.82, Std: 18.56
# Epoch 180/1000: Mean rewards: 43.24, Std: 17.5
# Epoch 200/1000: Mean rewards: 43.48, Std: 15.15
# Epoch 220/1000: Mean rewards: 47.58, Std: 24.13
# Epoch 240/1000: Mean rewards: 40.02, Std: 19.67
# Epoch 260/1000: Mean rewards: 39.54, Std: 17.27
# Epoch 280/1000: Mean rewards: 44.18, Std: 23.11
# Epoch 300/1000: Mean rewards: 45.08, Std: 22.3
# Epoch 320/1000: Mean rewards: 47.92, Std: 22.0
# Epoch 340/1000: Mean rewards: 51.56, Std: 24.5
# Epoch 360/1000: Mean rewards: 45.68, Std: 26.15
# Epoch 380/1000: Mean rewards: 43.72, Std: 19.08
# Epoch 400/1000: Mean rewards: 44.92, Std: 18.26
# Epoch 420/1000: Mean rewards: 53.16, Std: 22.23
# Epoch 440/1000: Mean rewards: 52.4, Std: 20.85
# Epoch 460/1000: Mean rewards: 47.88, Std: 17.77
# Epoch 480/1000: Mean rewards: 56.38, Std: 22.73
# Epoch 500/1000: Mean rewards: 67.82, Std: 37.95
# Epoch 520/1000: Mean rewards: 66.0, Std: 32.91
# Epoch 540/1000: Mean rewards: 43.62, Std: 14.41
# Epoch 560/1000: Mean rewards: 72.4, Std: 37.39
# Epoch 580/1000: Mean rewards: 83.6, Std: 46.08
# Epoch 600/1000: Mean rewards: 77.7, Std: 40.11
# Epoch 620/1000: Mean rewards: 144.86, Std: 44.28
# Epoch 640/1000: Mean rewards: 156.44, Std: 39.4
# Epoch 660/1000: Mean rewards: 157.42, Std: 46.49
# Epoch 680/1000: Mean rewards: 112.78, Std: 24.42
# Epoch 700/1000: Mean rewards: 39.22, Std: 12.36
# Epoch 720/1000: Mean rewards: 161.04, Std: 38.24
# Epoch 740/1000: Mean rewards: 131.76, Std: 19.15
# Epoch 760/1000: Mean rewards: 160.6, Std: 35.01
# Epoch 780/1000: Mean rewards: 151.68, Std: 37.09
# Epoch 800/1000: Mean rewards: 132.88, Std: 22.29
# Epoch 820/1000: Mean rewards: 177.44, Std: 73.0
# Epoch 840/1000: Mean rewards: 151.92, Std: 33.64
# Epoch 860/1000: Mean rewards: 156.48, Std: 28.28
# Epoch 880/1000: Mean rewards: 133.58, Std: 23.26
# Epoch 900/1000: Mean rewards: 115.06, Std: 48.23
# Epoch 920/1000: Mean rewards: 159.7, Std: 26.37
# Epoch 940/1000: Mean rewards: 172.06, Std: 38.7
# Epoch 960/1000: Mean rewards: 162.86, Std: 44.11
# Epoch 980/1000: Mean rewards: 167.16, Std: 47.57
# Epoch 999/1000: Mean rewards: 81.54, Std: 34.8
# <img src="data:image/png;base64,..." width="639.9999861283738">
# The training was done over a total of 4277 episodes
# NALU
# Mean success : 80.35 +- 27.31
#
# Epoch 0/1000: Mean rewards: 21.9, Std: 12.03
# Epoch 20/1000: Mean rewards: 23.02, Std: 13.3
# Epoch 40/1000: Mean rewards: 23.34, Std: 15.41
# Epoch 60/1000: Mean rewards: 20.06, Std: 10.85
# Epoch 80/1000: Mean rewards: 21.22, Std: 10.03
# Epoch 100/1000: Mean rewards: 19.1, Std: 7.31
# Epoch 120/1000: Mean rewards: 23.54, Std: 11.18
# Epoch 140/1000: Mean rewards: 26.78, Std: 14.65
# Epoch 160/1000: Mean rewards: 33.26, Std: 19.21
# Epoch 180/1000: Mean rewards: 35.78, Std: 28.58
# Epoch 200/1000: Mean rewards: 44.34, Std: 35.89
# Epoch 220/1000: Mean rewards: 34.24, Std: 17.06
# Epoch 240/1000: Mean rewards: 45.94, Std: 32.53
# Epoch 260/1000: Mean rewards: 44.8, Std: 27.92
# Epoch 280/1000: Mean rewards: 52.36, Std: 37.0
# Epoch 300/1000: Mean rewards: 64.34, Std: 43.69
# Epoch 320/1000: Mean rewards: 81.66, Std: 44.53
# Epoch 340/1000: Mean rewards: 94.2, Std: 45.48
# Epoch 360/1000: Mean rewards: 92.66, Std: 46.8
# Epoch 380/1000: Mean rewards: 103.06, Std: 40.64
# Epoch 400/1000: Mean rewards: 116.84, Std: 74.84
# Epoch 420/1000: Mean rewards: 125.6, Std: 56.81
# Epoch 440/1000: Mean rewards: 125.28, Std: 53.74
# Epoch 460/1000: Mean rewards: 134.8, Std: 54.16
# Epoch 480/1000: Mean rewards: 122.24, Std: 58.01
# Epoch 500/1000: Mean rewards: 139.64, Std: 65.41
# Epoch 520/1000: Mean rewards: 148.1, Std: 62.75
# Epoch 540/1000: Mean rewards: 146.44, Std: 69.42
# Epoch 560/1000: Mean rewards: 147.86, Std: 73.79
# Epoch 580/1000: Mean rewards: 163.9, Std: 81.87
# Epoch 600/1000: Mean rewards: 150.94, Std: 61.77
# Epoch 620/1000: Mean rewards: 175.16, Std: 76.48
# Epoch 640/1000: Mean rewards: 145.1, Std: 59.14
# Epoch 660/1000: Mean rewards: 147.12, Std: 46.22
# Epoch 680/1000: Mean rewards: 171.16, Std: 87.92
# Epoch 700/1000: Mean rewards: 172.26, Std: 83.07
# Epoch 720/1000: Mean rewards: 182.34, Std: 73.75
# Epoch 740/1000: Mean rewards: 176.3, Std: 82.55
# Epoch 760/1000: Mean rewards: 183.46, Std: 79.33
# Epoch 780/1000: Mean rewards: 171.26, Std: 97.67
# Epoch 800/1000: Mean rewards: 180.0, Std: 96.9
# Epoch 820/1000: Mean rewards: 187.32, Std: 99.11
# Epoch 840/1000: Mean rewards: 196.04, Std: 77.13
# Epoch 860/1000: Mean rewards: 175.48, Std: 77.17
# Epoch 880/1000: Mean rewards: 178.84, Std: 70.6
# Epoch 900/1000: Mean rewards: 169.28, Std: 75.78
# Epoch 920/1000: Mean rewards: 178.98, Std: 58.09
# Epoch 940/1000: Mean rewards: 190.7, Std: 75.28
# Epoch 960/1000: Mean rewards: 202.36, Std: 84.89
# Epoch 980/1000: Mean rewards: 198.84, Std: 94.55
# Epoch 999/1000: Mean rewards: 201.68, Std: 85.74
# <img src="data:image/png;base64,..." width="639.9999861283738">
# The training was done over a total of 3919 episodes
# ReRegualizedLinearMNAC
# Mean success : 202.82 +- 86.44
#
# Epoch 0/1000: Mean rewards: 37.12, Std: 22.45
# Epoch 20/1000: Mean rewards: 178.98, Std: 83.89
# Epoch 40/1000: Mean rewards: 228.12, Std: 96.87
# Epoch 60/1000: Mean rewards: 338.22, Std: 137.76
# Epoch 80/1000: Mean rewards: 195.18, Std: 88.38
# Epoch 100/1000: Mean rewards: 325.8, Std: 128.78
# Epoch 120/1000: Mean rewards: 371.08, Std: 112.31
# Epoch 140/1000: Mean rewards: 334.78, Std: 116.71
# Epoch 160/1000: Mean rewards: 422.82, Std: 115.62
# Epoch 180/1000: Mean rewards: 345.84, Std: 113.54
# Epoch 200/1000: Mean rewards: 458.68, Std: 76.1
# Epoch 220/1000: Mean rewards: 442.46, Std: 86.08
# Epoch 240/1000: Mean rewards: 395.4, Std: 109.17
# Epoch 260/1000: Mean rewards: 453.58, Std: 98.13
# Epoch 280/1000: Mean rewards: 209.84, Std: 72.63
# Epoch 300/1000: Mean rewards: 269.02, Std: 94.47
# Epoch 320/1000: Mean rewards: 365.38, Std: 120.2
# Epoch 340/1000: Mean rewards: 485.8, Std: 52.88
# Epoch 360/1000: Mean rewards: 497.14, Std: 17.51
# Early stopping !
# <img src="data:image/png;base64,..." width="639.9999861283738">
# The training was done over a total of 328 episodes
# ReRegualizedLinearNAC
# Mean success : 499.18 +- 5.85
#
# Wall time: 49min 7s

# %% [markdown]
# #### Evaluation

# %%
masses = np.geomspace(0.2, 2, num=21)
min_mass = masses[:-1]
max_mass = masses[1:]
n_eval = 100
print(max_mass)
rewards = np.zeros((len(agents), len(max_mass), n_eval))
pbar = tqdm.notebook.tqdm(total=len(max_mass) * len(agents))
for j, m in enumerate(max_mass):
    for i, a in enumerate(agents):
        try:
            rws = eval_agent(a, n_eval, min_mass[i], max_mass[i])
            rewards[i, j] = rws
            pbar.update(1)
        except:
            print(f'Mass : {m:.2f}, agent : {name_agents[i]}')
pbar.close()
# Out:
# [0.22440369 0.25178508 0.28250751 0.31697864 0.35565588 0.39905246
#  0.44774423 0.50237729 0.56367659 0.63245553 0.70962678 0.79621434
#  0.89336718 1.00237447 1.12468265 1.26191469 1.41589157 1.58865647
#  1.78250188 2.        ]
# HBox(children=(IntProgress(value=0, max=120), HTML(value='')))

# %%
np.save('../figures/rewards_only_actor', rewards)

# %%
rewards = np.load('../figures/rewards_only_actor.npy')

# %%
rewards.shape
# Out:
# (6, 20, 100)

# %%
fig = plt.figure(figsize=(8, 5))
for i in range(rewards.shape[0]):
    if i == 0:
        plt.errorbar(max_mass, rewards[i].mean(axis=1)/500, yerr=rewards[i].std(axis=1)/500,
                     barsabove=True, capsize=5, label=name_agents[i], color='black', linewidth=5, elinewidth=1)
    else:
        plt.errorbar(max_mass, rewards[i].mean(axis=1)/500, yerr=rewards[i].std(axis=1)/500,
                     barsabove=True, capsize=5, label=name_agents[i], linewidth=3, elinewidth=1)
ax = fig.axes[0]
ax.legend()
# ax.set_xlim(0.05, max_mass[-1])
ax.set_xscale('log')
# ax.set_ylim(0, 1)
# ax.set_yscale('log')
ax.set_ylabel('Reward')
ax.set_xlabel('Max mass')
# plt.savefig('../figures/layer_type_agents.pdf', format='pdf')
# Out:
# <img src="data:image/png;base64,..." width="799.9999826604674">
# Text(0.5, 0, 'Max mass')

# %% [markdown]
# ### Both critic and actor

# %%
agents_both = []
name_agents = ['ReLU', 'MNAC', 'NAC', 'NALU', 'ReRegualizedLinearMNAC', 'ReRegualizedLinearNAC']

# %%
# %%time
for unit_name in name_agents:
    a_net = NetworkNAU(unit_name, input_size=5, hidden_size=hidden_size, output_size=2, actor=True)
    v_net = NetworkNAU(unit_name, input_size=5, hidden_size=hidden_size, output_size=1)
    agent = A2CAgentRNN(config_a2c, range_train=range_train, range_eval=range_train,
                        a_net=a_net, v_net=v_net, LSTM=False, reg=1)
    agent.training_batch(1000, 256, disp=True)
    print(unit_name)
    eval_agent(agent, 100, range_train[0], range_train[1], disp=True)
    agents_both.append(agent)
    print('')
# Out:
# Epoch 0/1000: Mean rewards: 30.3, Std: 16.05
# Epoch 20/1000: Mean rewards: 106.84, Std: 55.83
# Epoch 40/1000: Mean rewards: 148.88, Std: 59.48
# Epoch 60/1000: Mean rewards: 181.78, Std: 88.78
# Epoch 80/1000: Mean rewards: 175.12, Std: 81.45
# Epoch 100/1000: Mean rewards: 204.04, Std: 97.66
# Epoch 120/1000: Mean rewards: 207.98, Std: 85.64
# Epoch 140/1000: Mean rewards: 214.52, Std: 71.12
# Epoch 160/1000: Mean rewards: 210.58, Std: 81.81
# Epoch 180/1000: Mean rewards: 233.6, Std: 84.3
# Epoch 200/1000: Mean rewards: 324.54, Std: 112.73
# Epoch 220/1000: Mean rewards: 334.16, Std: 109.85
# Epoch 240/1000: Mean rewards: 357.62, Std: 113.67
# Epoch 260/1000: Mean rewards: 373.88, Std: 119.84
# Epoch 280/1000: Mean rewards: 366.84, Std: 122.82
# Epoch 300/1000: Mean rewards: 366.04, Std: 109.34
# Epoch 320/1000: Mean rewards: 260.74, Std: 110.96
# Epoch 340/1000: Mean rewards: 279.9, Std: 111.96
# Epoch 360/1000: Mean rewards: 252.74, Std: 115.93
# Epoch 380/1000: Mean rewards: 270.84, Std: 120.55
# Epoch 400/1000: Mean rewards: 300.3, Std: 136.76
# Epoch 420/1000: Mean rewards: 363.14, Std: 142.16
# Epoch 440/1000: Mean rewards: 218.84, Std: 61.58
# Epoch 460/1000: Mean rewards: 371.8, Std: 127.33
# Epoch 480/1000: Mean rewards: 279.76, Std: 105.18
# Epoch 500/1000: Mean rewards: 431.08, Std: 84.61
# Epoch 520/1000: Mean rewards: 304.26, Std: 111.31
# Epoch 540/1000: Mean rewards: 377.46, Std: 136.5
# Epoch 560/1000: Mean rewards: 278.84, Std: 107.05
# Epoch 580/1000: Mean rewards: 393.7, Std: 122.26
# Epoch 600/1000: Mean rewards: 413.6, Std: 103.01
# Epoch 620/1000: Mean rewards: 367.52, Std: 131.34
# Epoch 640/1000: Mean rewards: 421.76, Std: 99.14
# Epoch 660/1000: Mean rewards: 452.78, Std: 84.9
# Epoch 680/1000: Mean rewards: 470.02, Std: 70.72
# Epoch 700/1000: Mean rewards: 474.08, Std: 66.26
# Epoch 720/1000: Mean rewards: 361.66, Std: 135.98
# Epoch 740/1000: Mean rewards: 445.88, Std: 102.51
# Epoch 760/1000: Mean rewards: 439.48, Std: 110.05
# Epoch 780/1000: Mean rewards: 447.42, Std: 92.85
# Epoch 800/1000: Mean rewards: 456.1, Std: 70.27
# Epoch 820/1000: Mean rewards: 467.66, Std: 93.12
# Epoch 840/1000: Mean rewards: 463.16, Std: 83.41
# Epoch 860/1000: Mean rewards: 433.86, Std: 117.25
# Epoch 880/1000: Mean rewards: 458.38, Std: 103.05
# Epoch 900/1000: Mean rewards: 408.14, Std: 122.42
# Epoch 920/1000: Mean rewards: 391.4, Std: 137.35
# Epoch 940/1000: Mean rewards: 462.14, Std: 91.72
# Epoch 960/1000: Mean rewards: 439.8, Std: 103.52
# Epoch 980/1000: Mean rewards: 478.66, Std: 67.67
# Epoch 999/1000: Mean rewards: 455.74, Std: 86.73
# <img src="data:image/png;base64,..." width="639.9999861283738">
# The training was done over a total of 855 episodes
# ReLU
# Mean success : 448.04 +- 98.10
#
# Epoch 0/1000: Mean rewards: 21.9, Std: 12.03
# Epoch 20/1000: Mean rewards: 23.02, Std: 13.3
# Epoch 40/1000: Mean rewards: 22.68, Std: 11.65
# Epoch 60/1000: Mean rewards: 19.92, Std: 10.32
# Epoch 80/1000: Mean rewards: 24.1, Std: 11.23
# Epoch 100/1000: Mean rewards: 20.1, Std: 9.85
# Epoch 120/1000: Mean rewards: 21.02, Std: 9.98
# Epoch 140/1000: Mean rewards: 23.04, Std: 11.71
# Epoch 160/1000: Mean rewards: 24.02, Std: 14.84
# Epoch 180/1000: Mean rewards: 23.14, Std: 13.62
# Epoch 200/1000: Mean rewards: 20.64, Std: 9.03
# Epoch 220/1000: Mean rewards: 25.84, Std: 16.94
# Epoch 240/1000: Mean rewards: 19.5, Std: 9.28
# Epoch 260/1000: Mean rewards: 19.78, Std: 13.78
# Epoch 280/1000: Mean rewards: 22.6, Std: 10.75
# Epoch 300/1000: Mean rewards: 22.78, Std: 11.62
# Epoch 320/1000: Mean rewards: 23.02, Std: 12.68
# Epoch 340/1000: Mean rewards: 19.68, Std: 8.0
# Epoch 360/1000: Mean rewards: 20.34, Std: 10.99
# Epoch 380/1000: Mean rewards: 22.78, Std: 12.52
# Epoch 400/1000: Mean rewards: 22.18, Std: 12.04
# Epoch 420/1000: Mean rewards: 22.7, Std: 9.54
# Epoch 440/1000: Mean rewards: 22.66, Std: 16.3
# Epoch 460/1000: Mean rewards: 21.92, Std: 11.17
# Epoch 480/1000: Mean rewards: 27.46, Std: 14.5
# Epoch 500/1000: Mean rewards: 21.02, Std: 15.57
# Epoch 520/1000: Mean rewards: 22.22, Std: 16.68
# Epoch 540/1000: Mean rewards: 21.76, Std: 8.76
# Epoch 560/1000: Mean rewards: 21.92, Std: 10.83
# Epoch 580/1000: Mean rewards: 21.44, Std: 11.16
# Epoch 600/1000: Mean rewards: 20.58, Std: 10.79
# Epoch 620/1000: Mean rewards: 22.56, Std: 11.3
# Epoch 640/1000: Mean rewards: 20.5, Std: 9.83
# Epoch 660/1000: Mean rewards: 21.02, Std: 10.25
# Epoch 680/1000: Mean rewards: 19.88, Std: 12.83
# Epoch 700/1000: Mean rewards: 22.4, Std: 13.32
# Epoch 720/1000: Mean rewards: 24.64, Std: 13.53
# Epoch 740/1000: Mean rewards: 22.3, Std: 10.93
# Epoch 760/1000: Mean rewards: 20.46, Std: 9.6
# Epoch 780/1000: Mean rewards: 22.66, Std: 12.18
# Epoch 800/1000: Mean rewards: 23.18, Std: 12.86
# Epoch 820/1000: Mean rewards: 21.16, Std: 12.16
# Epoch 840/1000: Mean rewards: 19.58, Std: 7.65
# Epoch 860/1000: Mean rewards: 22.18, Std: 11.97
# Epoch 880/1000: Mean rewards: 22.52, Std: 12.08
# Epoch 900/1000: Mean rewards: 22.76, Std: 11.76
# Epoch 920/1000: Mean rewards: 21.32, Std: 9.83
# Epoch 940/1000: Mean rewards: 22.66, Std: 13.26
# Epoch 960/1000: Mean rewards: 22.5, Std: 12.86
# Epoch 980/1000: Mean rewards: 23.62, Std: 11.99
# Epoch 999/1000: Mean rewards: 23.52, Std: 11.53
# <img src="data:image/png;base64,..." width="639.9999861283738">
# The training was done over a total of 11652 episodes
# MNAC
# Mean success : 20.76 +- 10.38
#
# Epoch 0/1000: Mean rewards: 23.12, Std: 10.95
# Epoch 20/1000: Mean rewards: 136.84, Std: 63.25
# Epoch 40/1000: Mean rewards: 190.46, Std: 84.76
# Epoch 60/1000: Mean rewards: 224.94, Std: 89.67
# Epoch 80/1000: Mean rewards: 247.76, Std: 86.03
# Epoch 100/1000: Mean rewards: 253.5, Std: 87.01
# Epoch 120/1000: Mean rewards: 341.8, Std: 127.74
# Epoch 140/1000: Mean rewards: 262.82, Std: 126.22
# Epoch 160/1000: Mean rewards: 256.78, Std: 91.05
# Epoch 180/1000: Mean rewards: 344.66, Std: 137.05
# Epoch 200/1000: Mean rewards: 371.38, Std: 131.05
# Epoch 220/1000: Mean rewards: 377.92, Std: 130.11
# Epoch 240/1000: Mean rewards: 361.9, Std: 127.46
# Epoch 260/1000: Mean rewards: 355.64, Std: 109.48
# Epoch 280/1000: Mean rewards: 361.0, Std: 130.4
# Epoch 300/1000: Mean rewards: 359.12, Std: 121.86
# Epoch 320/1000: Mean rewards: 404.1, Std: 119.32
# Epoch 340/1000: Mean rewards: 422.5, Std: 106.75
# Epoch 360/1000: Mean rewards: 400.08, Std: 126.72
# Epoch 380/1000: Mean rewards: 420.74, Std: 113.75
# Epoch 400/1000: Mean rewards: 414.84, Std: 110.63
# Epoch 420/1000: Mean rewards: 346.6, Std: 100.32
# Epoch 440/1000: Mean rewards: 353.4, Std: 105.23
# Epoch 460/1000: Mean rewards: 447.66, Std: 93.5
# Epoch 480/1000: Mean rewards: 453.26, Std: 87.2
# Epoch 500/1000: Mean rewards: 465.46, Std: 68.57
# Epoch 520/1000: Mean rewards: 439.4, Std: 85.18
# Epoch 540/1000: Mean rewards: 470.08, Std: 75.76
# Epoch 560/1000: Mean rewards: 477.92, Std: 52.3
# Epoch 580/1000: Mean rewards: 465.06, Std: 74.75
# Epoch 600/1000: Mean rewards: 475.8, Std: 64.25
# Epoch 620/1000: Mean rewards: 482.32, Std: 56.56
# Epoch 640/1000: Mean rewards: 488.72, Std: 45.78
# Epoch 660/1000: Mean rewards: 463.96, Std: 69.31
# Epoch 680/1000: Mean rewards: 480.82, Std: 59.9
# Epoch 700/1000: Mean rewards: 482.66, Std: 65.91
# Epoch 720/1000: Mean rewards: 488.68, Std: 40.41
# Epoch 740/1000: Mean rewards: 475.06, Std: 72.63
# Epoch 760/1000: Mean rewards: 498.08, Std: 9.41
# Early stopping !
# <img src="data:image/png;base64,..." width="639.9999861283738">
# The training was done over a total of 612 episodes
# NAC
# Mean success : 482.51 +- 56.25
#
# Epoch 0/1000: Mean rewards: 9.38, Std: 0.75
# Epoch 20/1000: Mean rewards: 9.4, Std: 0.8
# Epoch 40/1000: Mean rewards: 9.2, Std: 0.8
# Epoch 60/1000: Mean rewards: 9.3, Std: 0.81
# Epoch 80/1000: Mean rewards: 9.16, Std: 0.76
# Epoch 100/1000: Mean rewards: 9.42, Std: 0.67
# Epoch 120/1000: Mean rewards: 9.12, Std: 0.68
# Epoch 140/1000: Mean rewards: 9.16, Std: 0.73
# Epoch 160/1000: Mean rewards: 9.36, Std: 0.79
# Epoch 180/1000: Mean rewards: 9.4, Std: 0.69
# Epoch 200/1000: Mean rewards: 9.26, Std: 0.72
# Epoch 220/1000: Mean rewards: 9.16, Std: 0.7
# Epoch 240/1000: Mean rewards: 9.4, Std: 0.8
# Epoch 260/1000: Mean rewards: 9.34, Std: 0.76
# Epoch 280/1000: Mean rewards: 9.44, Std: 0.8
# Epoch 300/1000: Mean rewards: 9.32, Std: 0.73
# Epoch 320/1000: Mean rewards: 9.22, Std: 0.67
# Epoch 340/1000: Mean rewards: 9.26, Std: 0.69
# Epoch 360/1000: Mean rewards: 9.16, Std: 0.81
# Epoch 380/1000: Mean rewards: 9.34, Std: 0.82
# Epoch 400/1000: Mean rewards: 9.04, Std: 0.75
# Epoch 420/1000: Mean rewards: 9.32, Std: 0.73
# Epoch 440/1000: Mean rewards: 9.16, Std: 0.73
# Epoch 460/1000: Mean rewards: 9.28, Std: 0.75
# Epoch 480/1000: Mean rewards: 9.34, Std: 0.79
# Epoch 500/1000: Mean rewards: 9.08, Std: 0.72
# Epoch 520/1000: Mean rewards: 9.14, Std: 0.77
# Epoch 540/1000: Mean rewards: 9.44, Std: 0.75
# Epoch 560/1000: Mean rewards: 9.28, Std: 0.8
# Epoch 580/1000: Mean rewards: 9.26, Std: 0.72
# Epoch 600/1000: Mean rewards: 9.32, Std: 0.73
# Epoch 620/1000: Mean rewards: 9.28, Std: 0.72
# Epoch 640/1000: Mean rewards: 9.42, Std: 0.64
# Epoch 660/1000: Mean rewards: 9.14, Std: 0.69
# Epoch 680/1000: Mean rewards: 34.62, Std: 15.13
# Epoch 700/1000: Mean rewards: 35.58, Std: 12.75
# Epoch 720/1000: Mean rewards: 39.3, Std: 19.33
# Epoch 740/1000: Mean rewards: 34.6, Std: 15.25
# Epoch 760/1000: Mean rewards: 36.78, Std: 17.85
# Epoch 780/1000: Mean rewards: 39.9, Std: 15.96
# Epoch 800/1000: Mean rewards: 44.6, Std: 17.78
# Epoch 820/1000: Mean rewards: 45.08, Std: 18.62
# Epoch 840/1000: Mean rewards: 30.48, Std: 10.23
# Epoch 860/1000: Mean rewards: 45.44, Std: 16.48
# Epoch 880/1000: Mean rewards: 39.42, Std: 13.49
# Epoch 900/1000: Mean rewards: 43.34, Std: 17.33
# Epoch 920/1000: Mean rewards: 46.12, Std: 15.77
# Epoch 940/1000: Mean rewards: 43.74, Std: 16.55
# Epoch 960/1000: Mean rewards: 43.8, Std: 18.05
# Epoch 980/1000: Mean rewards: 49.6, Std: 19.87
# Epoch 999/1000: Mean rewards: 48.5, Std: 16.59
# <img src="data:image/png;base64,..." width="639.9999861283738">
# The training was done over a total of 20410 episodes
# NALU
# Mean success : 48.20 +- 15.55
#
# Epoch 0/1000: Mean rewards: 21.9, Std: 12.03
# Epoch 20/1000: Mean rewards: 23.02, Std: 13.3
# Epoch 40/1000: Mean rewards: 22.68, Std: 11.65
# Epoch 60/1000: Mean rewards: 19.92, Std: 10.32
# Epoch 80/1000: Mean rewards: 24.1, Std: 11.23
# Epoch 100/1000: Mean rewards: 19.88, Std: 9.83
# Epoch 120/1000: Mean rewards: 21.98, Std: 10.73
# Epoch 140/1000: Mean rewards: 26.74, Std: 14.77
# Epoch 160/1000: Mean rewards: 30.48, Std: 19.58
# Epoch 180/1000: Mean rewards: 30.34, Std: 18.16
# Epoch 200/1000: Mean rewards: 31.62, Std: 16.86
# Epoch 220/1000: Mean rewards: 40.28, Std: 28.86
# Epoch 240/1000: Mean rewards: 41.5, Std: 28.5
# Epoch 260/1000: Mean rewards: 34.62, Std: 24.33
# Epoch 280/1000: Mean rewards: 47.78, Std: 33.29
# Epoch 300/1000: Mean rewards: 50.6, Std: 34.48
# Epoch 320/1000: Mean rewards: 52.88, Std: 31.74
# Epoch 340/1000: Mean rewards: 62.56, Std: 40.96
# Epoch 360/1000: Mean rewards: 57.38, Std: 31.68
# Epoch 380/1000: Mean rewards: 57.36, Std: 38.07
# Epoch 400/1000: Mean rewards: 65.76, Std: 36.61
# Epoch 420/1000: Mean rewards: 55.8, Std: 33.14
# Epoch 440/1000: Mean rewards: 72.58, Std: 48.78
# Epoch 460/1000: Mean rewards: 70.04, Std: 45.62
# Epoch 480/1000: Mean rewards: 72.52, Std: 42.9
# Epoch 500/1000: Mean rewards: 77.38, Std: 49.61
# Epoch 520/1000: Mean rewards: 76.94, Std: 53.33
# Epoch 540/1000: Mean rewards: 73.76, Std: 43.06
# Epoch 560/1000: Mean rewards: 89.42, Std: 49.93
# Epoch 580/1000: Mean rewards: 98.42, Std: 56.92
# Epoch 600/1000: Mean rewards: 117.98, Std: 56.25
# Epoch 620/1000: Mean rewards: 124.56, Std: 67.89
# Epoch 640/1000: Mean rewards: 114.5, Std: 63.51
# Epoch 660/1000: Mean rewards: 124.68, Std: 66.59
# Epoch 680/1000: Mean rewards: 119.0, Std: 59.23
# Epoch 700/1000: Mean rewards: 133.44, Std: 59.18
# Epoch 720/1000: Mean rewards: 133.5, Std: 54.64
# Epoch 740/1000: Mean rewards: 131.88, Std: 53.43
# Epoch 760/1000: Mean rewards: 148.94, Std: 84.94
# Epoch 780/1000: Mean rewards: 140.98, Std: 71.52
# Epoch 800/1000: Mean rewards: 162.0, Std: 68.29
# Epoch 820/1000: Mean rewards: 154.8, Std: 65.45
# Epoch 840/1000: Mean rewards: 141.8, Std: 47.48
# Epoch 860/1000: Mean rewards: 151.0, Std: 67.52
# Epoch 880/1000: Mean rewards: 143.32, Std: 63.62
# Epoch 900/1000: Mean rewards: 146.76, Std: 66.27
# Epoch 920/1000: Mean rewards: 162.58, Std: 84.31
# Epoch 940/1000: Mean rewards: 156.98, Std: 57.22
# Epoch 960/1000: Mean rewards: 176.86, Std: 101.89
# Epoch 980/1000: Mean rewards: 160.84, Std: 68.63
# Epoch 999/1000: Mean rewards: 161.08, Std: 79.86
# <img src="data:image/png;base64,..." width="639.9999861283738">
# The training was done over a total of 4615 episodes
# ReRegualizedLinearMNAC
# Mean success : 160.02 +- 80.38
#
# Epoch 0/1000: Mean rewards: 25.58, Std: 14.82
# Epoch 20/1000: Mean rewards: 133.54, Std: 52.57
# Epoch 40/1000: Mean rewards: 117.0, Std: 58.89
# Epoch 60/1000: Mean rewards: 203.92, Std: 109.97
# Epoch 80/1000: Mean rewards: 309.82, Std: 113.39
# Epoch 100/1000: Mean rewards: 329.54, Std: 141.4
# Epoch 120/1000: Mean rewards: 323.86, Std: 123.11
# Epoch 140/1000: Mean rewards: 351.72, Std: 145.66
# Epoch 160/1000: Mean rewards: 372.08, Std: 135.32
# Epoch 180/1000: Mean rewards: 334.1, Std: 141.03
# Epoch 200/1000: Mean rewards: 351.16, Std: 121.62
# Epoch 220/1000: Mean rewards: 423.34, Std: 113.93
# Epoch 240/1000: Mean rewards: 402.0, Std: 103.53
# Epoch 260/1000: Mean rewards: 481.44, Std: 53.82
# Epoch 280/1000: Mean rewards: 472.22, Std: 71.09
# Epoch 300/1000: Mean rewards: 444.18, Std: 78.1
# Epoch 320/1000: Mean rewards: 494.46, Std: 27.18
# Early stopping !
# <img src="data:image/png;base64,..." width="639.9999861283738">
# The training was done over a total of 371 episodes
# ReRegualizedLinearNAC
# Mean success : 484.94 +- 59.92
#
# Wall time: 44min 32s

# %% [markdown]
# #### Evaluation

# %%
masses = np.geomspace(0.2, 2, num=21)
min_mass = masses[:-1]
max_mass = masses[1:]
n_eval = 100
print(max_mass)
rewards = np.zeros((len(agents_both), len(max_mass), n_eval))
pbar = tqdm.notebook.tqdm(total=len(max_mass) * len(agents_both))
for j, m in enumerate(max_mass):
    for i, a in enumerate(agents_both):
        try:
            rws = eval_agent(a, n_eval, min_mass[i], m)
            rewards[i, j] = rws
        except:
            print(f'Exception model {name_agents[i]} mass {m:.2f}')
            pass
        pbar.update(1)
pbar.close()
# Out:
# [0.22440369 0.25178508 0.28250751 0.31697864 0.35565588 0.39905246
#  0.44774423 0.50237729 0.56367659 0.63245553 0.70962678 0.79621434
#  0.89336718 1.00237447 1.12468265 1.26191469 1.41589157 1.58865647
#  1.78250188 2.        ]
# HBox(children=(IntProgress(value=0, max=120), HTML(value='')))
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x0000028FA3F0AD48>
# Traceback (most recent call last):
#   File "C:\tools\Anaconda3\lib\site-packages\tqdm\notebook.py", line 227, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception model MNAC mass 1.59
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x0000028FA3F0AD48>
# Traceback (most recent call last):
#   File "C:\tools\Anaconda3\lib\site-packages\tqdm\notebook.py", line 227, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception model ReRegualizedLinearMNAC mass 1.59
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x0000028FA3F0AD48>
# Traceback (most recent call last):
#   File "C:\tools\Anaconda3\lib\site-packages\tqdm\notebook.py", line 227, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception model ReRegualizedLinearMNAC mass 1.78
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x0000028FA3F0AD48>
# Traceback (most recent call last):
#   File "C:\tools\Anaconda3\lib\site-packages\tqdm\notebook.py", line 227, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception model MNAC mass 2.00
# Exception ignored in: <generator object tqdm_notebook.__iter__ at 0x0000028FA3F0AD48>
# Traceback (most recent call last):
#   File "C:\tools\Anaconda3\lib\site-packages\tqdm\notebook.py", line 227, in __iter__
#     self.sp(bar_style='danger')
# AttributeError: 'tqdm_notebook' object has no attribute 'sp'
# Exception model ReRegualizedLinearMNAC mass 2.00

# %%
np.save('../figures/rewards_both', rewards)

# %%
fig = plt.figure(figsize=(8, 5))
for i, a in enumerate(agents):
    if i == 0:
        plt.errorbar(max_mass, rewards[i].mean(axis=1)/500, yerr=rewards[i].std(axis=1)/500,
                     barsabove=True, capsize=5, label=name_agents[i], color='black', linewidth=5, elinewidth=1)
    else:
        plt.errorbar(max_mass, rewards[i].mean(axis=1)/500, yerr=rewards[i].std(axis=1)/500,
                     barsabove=True, capsize=5, label=name_agents[i], linewidth=3, elinewidth=1)
ax = fig.axes[0]
ax.legend()
# ax.set_xlim(0.05, max_mass[-1])
ax.set_xscale('log')
# ax.set_ylim(0, 1)
# ax.set_yscale('log')
ax.set_ylabel('Reward')
ax.set_xlabel('Max mass')
plt.savefig('../figures/layer_type_both.pdf', format='pdf')
# Out:
# <img src="data:image/png;base64,..." width="799.9999826604674">

# %% [markdown]
# # MountainCar

# %%
env_id = 'MountainCar-v0'
value_learning_rate = 0.1
actor_learning_rate = 0.1
gamma = 0.9
entropy = 1
seed = 1

config_a2c = {
    'env_id': env_id,
    'gamma': gamma,
    'seed': seed,
    'value_network': {'learning_rate': value_learning_rate},
    'actor_network': {'learning_rate': actor_learning_rate},
    'entropy': entropy
}

print("Current config_a2c is:")
pprint(config_a2c)
# Out:
# Current config_a2c is:
# {'actor_network': {'learning_rate': 0.1},
#  'entropy': 1,
#  'env_id': 'MountainCar-v0',
#  'gamma': 0.9,
#  'seed': 1,
#  'value_network': {'learning_rate': 0.1}}

# %%
env = gym.make(env_id)
# We wrap it in order to save our experiment on a file.
env = Monitor(env, "./gym-results", force=True)
env.reset()
done = False
obs = env.reset()
while not done:
    action = env.action_space.sample()
    obs, reward, done, info = env.step(action)
env.close()
show_video("./gym-results")

# %%
agent = A2CAgent(config_a2c)
rewards = agent.training_batch(1000, 256)
# Out:
# Epoch 0/1000: Mean rewards: -200.0, Std: 0.0
# Epoch 50/1000: Mean rewards: -200.0, Std: 0.0
# Epoch 100/1000: Mean rewards: -200.0, Std: 0.0
# Epoch 150/1000: Mean rewards: -200.0, Std: 0.0
# Epoch 200/1000: Mean rewards: -200.0, Std: 0.0
# Epoch 250/1000: Mean rewards: -200.0, Std: 0.0
# Epoch 300/1000: Mean rewards: -200.0, Std: 0.0
# Epoch 350/1000: Mean rewards: -200.0, Std: 0.0
# Epoch 400/1000: Mean rewards: -200.0, Std: 0.0
# Epoch 450/1000: Mean rewards: -200.0, Std: 0.0
# Epoch 500/1000: Mean rewards: -200.0, Std: 0.0
# Epoch 550/1000: Mean rewards: -200.0, Std: 0.0
# Epoch 600/1000: Mean rewards: -200.0, Std: 0.0
# Epoch 650/1000: Mean rewards: -200.0, Std: 0.0
# Epoch 700/1000: Mean rewards: -200.0, Std: 0.0
# Epoch 750/1000: Mean rewards: -200.0, Std: 0.0
# Epoch 800/1000: Mean rewards: -200.0, Std: 0.0
# Epoch 850/1000: Mean rewards: -200.0, Std: 0.0
# Epoch 900/1000: Mean rewards: -200.0, Std: 0.0
# Epoch 950/1000: Mean rewards: -200.0, Std: 0.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-78-fd36fc2093a3> in <module>
#       1 agent = A2CAgent(config_a2c)
# ----> 2 rewards = agent.training_batch(1000, 256)
#
# ~\Documents\Cours_3A\Object_recognition_and_CV\Project\RLfunctions.py in training_batch(self, epochs, batch_size)
#     186             for i in range(batch_size):
#     187                 observations[i] = observation
# --> 188                 actions[i] = self.actor_network.select_action(torch.tensor(observations[i], dtype=torch.float))
#     189                 values[i] = self.value_network.predict(torch.tensor(observations[i], dtype=torch.float))
#     190                 # step
#
# ~\Documents\Cours_3A\Object_recognition_and_CV\Project\RLfunctions.py in select_action(self, x)
#      77
#      78     def select_action(self, x):
# ---> 79         return torch.multinomial(self(x), 1).detach().numpy()
#      80
#      81
#
# c:\tools\anaconda3\envs\orcv\lib\site-packages\torch\nn\modules\module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# ~\Documents\Cours_3A\Object_recognition_and_CV\Project\RLfunctions.py in forward(self, x)
#      73         out = F.relu(self.fc1(x))
#      74         out = F.relu(self.fc2(out))
# ---> 75         out = F.softmax(self.fc3(out), dim=-1)
#      76         return out
#      77
#
# c:\tools\anaconda3\envs\orcv\lib\site-packages\torch\nn\functional.py in softmax(input, dim, _stacklevel, dtype)
#    1229         dim = _get_softmax_dim('softmax', input.dim(), _stacklevel)
#    1230     if dtype is None:
# -> 1231         ret = input.softmax(dim)
#    1232     else:
#    1233         ret = input.softmax(dim, dtype=dtype)
#
# KeyboardInterrupt:

# %% [markdown]
# # QLearning

# %%
env_id = 'CartPole-v1'
learning_rate = 1e-3
gamma = 0.999
entropy = 1
seed = 1

config_a2c = {
    'env_id': env_id,
    'gamma': gamma,
    'seed': seed,
    'learning_rate': learning_rate,
    'entropy': entropy
}

print("Current config_a2c is:")
pprint(config_a2c)
# Out:
# Current config_a2c is:
# {'entropy': 1,
#  'env_id': 'CartPole-v1',
#  'gamma': 0.999,
#  'learning_rate': 0.001,
#  'seed': 1}

# %%
# q = Qfunction(['ReLU', 'ReLU', 'ReLU'], input_size=5, hidden_size=[64, 128, 128, 32], output_size=2)
# q_eval = Qfunction(['ReLU', 'ReLU', 'ReLU'], input_size=5, hidden_size=[64, 128, 128, 32], output_size=2)
q = Qfunction(['ReLU', 'ReLU', 'ReLU'], input_size=5, hidden_size=[32, 32], output_size=2)
q_eval = Qfunction(['ReLU', 'ReLU', 'ReLU'], input_size=5, hidden_size=[32, 32], output_size=2)
range_mass = (0.1, 0.1)

# %%
agent = QTrainer(config_a2c, range_mass, range_mass, q, q_eval, eps_func=lambda r: max(0.9 - r, 0.05), capacity=10000)

# %%
agent.train_model(num_episodes=5000, eval_update=10, eval_every=50, batch_size=128)
# Out:
# HBox(children=(IntProgress(value=0, max=5000), HTML(value='')))
# Mean success : 9.38 +- 0.80
#
# optimizing
# Mean success : 9.38 +- 0.89
#
# Mean success : 9.16 +- 0.76
#
# Mean success : 9.44 +- 0.80
#
# Mean success : 9.42 +- 0.70
#
# Mean success : 9.30 +- 0.85
#
# Mean success : 9.42 +- 0.75
#
# Mean success : 9.14 +- 0.66
#
# Mean success : 9.36 +- 0.82
#
# Mean success : 9.38 +- 0.75
#
# Mean success : 9.26 +- 0.82
#
# Mean success : 9.22 +- 0.73
#
# Mean success : 9.26 +- 0.72
#
# Mean success : 9.26 +- 0.82
#
# Mean success : 9.44 +- 0.75
#
# Mean success : 9.36 +- 0.62
#
# Mean success : 9.44 +- 0.75
#
# Mean success : 9.36 +- 0.79
#
# Mean success : 9.22 +- 0.78
#
# Mean success : 9.44 +- 0.73
#
# Mean success : 9.46 +- 0.73
#
# Mean success : 9.42 +- 0.60
#
# Mean success : 9.28 +- 0.78
#
# Mean success : 9.30 +- 0.75
#
# Mean success : 9.24 +- 0.68
#
# Mean success : 9.36 +- 0.79
#
# Mean success : 9.18 +- 0.65
#
# Mean success : 9.54 +- 0.70
#
# Mean success : 9.32 +- 0.73
#
# Mean success : 9.20 +- 0.80
#
# Mean success : 9.16 +- 0.76
#
# Mean success : 9.50 +- 0.67
#
# Mean success : 9.10 +- 0.75
#
# Mean success : 9.36 +- 0.66
#
# Mean success : 9.36 +- 0.59
#
# Mean success : 9.20 +- 0.82
#
# Mean success : 9.16 +- 0.73
#
# Mean success : 9.30 +- 0.78
#
# Mean success : 9.14 +- 0.75
#
# Mean success : 9.46 +- 0.78
#
# Mean success : 9.32 +- 0.68
#
# Mean success : 9.28 +- 0.69
#
# Mean success : 9.50 +- 0.75
#
# Mean success : 9.40 +- 0.69
#
# Mean success : 9.48 +- 0.64
#
# Mean success : 9.38 +- 0.75
#
# Mean success : 9.38 +- 0.72
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-cb6ceb580859> in <module>
# ----> 1 agent.train_model(num_episodes=5000, eval_update=10, eval_every=50, batch_size=128)
#
# ~\Documents\Cours_3A\Object_recognition_and_CV\Project\NAU_RL.py in train_model(self, num_episodes, eval_update, eval_every, batch_size)
#     511                 else:
#     512                     eps = None
# --> 513                 action = self.Q.select_action(state, eps=eps)
#     514
#     515                 # predicted.append(state_action_val[0, action])
#
# ~\Documents\Cours_3A\Object_recognition_and_CV\Project\NAU_RL.py in select_action(self, state, eps)
#     441             choice = torch.tensor([[random.randrange(2)]], dtype=torch.long)
#     442         else:
# --> 443             choice = self(state).max(1)[1].view(1, 1) #.numpy().flatten()
#     444         return choice
#     445
#
# C:\tools\Anaconda3\lib\site-packages\torch\nn\modules\module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# ~\Documents\Cours_3A\Object_recognition_and_CV\Project\NAU_RL.py in forward(self, input)
#     419         #     input = l(input)
#     420         for l in self.layers[:-1]:
# --> 421             input = F.relu(l(input))
#     422         input = self.layers[-1](input)
#     423
#
# C:\tools\Anaconda3\lib\site-packages\torch\nn\modules\module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# C:\tools\Anaconda3\lib\site-packages\torch\nn\modules\linear.py in forward(self, input)
#      85
#      86     def forward(self, input):
# ---> 87         return F.linear(input, self.weight, self.bias)
#      88
#      89     def extra_repr(self):
#
# C:\tools\Anaconda3\lib\site-packages\torch\nn\functional.py in linear(input, weight, bias)
#    1368     if input.dim() == 2 and bias is not None:
#    1369         # fused op is marginally faster
# -> 1370         ret = torch.addmm(bias, input, weight.t())
#    1371     else:
#    1372         output = input.matmul(weight.t())
#
# KeyboardInterrupt:

# %%
from collections import namedtuple
Transition = namedtuple('Transition',
                        ('state', 'action', 'next_state', 'reward'))

# %%
t = Transition(*zip(*agent.memory.sample(10)))

# %%
t.state
# Out:
# (tensor([ 0.0107,  0.1967, -0.0155, -0.3294,  0.1506]),
#  tensor([-0.0078, -0.1960,  0.0099,  0.3126,  0.1198]),
#  tensor([ 0.0067,  0.1966, -0.0089, -0.3268,  0.1506]),
#  tensor([ 1.9301e-05,  1.9570e-01, -1.6468e-03, -3.0547e-01,  1.1977e-01]),
#  tensor([ 0.0029, -0.1962, -0.0049,  0.3170,  0.1506]),
#  tensor([-0.0046, -0.1944,  0.0047,  0.2770,  0.1336]),
#  tensor([ 8.4713e-05,  1.9513e-01, -3.0895e-03, -2.9278e-01,  1.1977e-01]),
#  tensor([-0.0038, -0.1953,  0.0028,  0.2966,  0.1198]),
#  tensor([-0.0049,  0.1950,  0.0062, -0.2910,  0.1506]),
#  tensor([ 0.0106, -0.1947, -0.0146,  0.2843,  0.1506]))

# %%
torch.cat(t.state)
# Out:
# tensor([ 1.0660e-02,  1.9669e-01, -1.5460e-02, -3.2935e-01,  1.5057e-01,
#         -7.7781e-03, -1.9600e-01,  9.9061e-03,  3.1256e-01,  1.1977e-01,
#          6.7276e-03,  1.9662e-01, -8.9247e-03, -3.2675e-01,  1.5057e-01,
#          1.9301e-05,  1.9570e-01, -1.6468e-03, -3.0547e-01,  1.1977e-01,
#          2.9081e-03, -1.9621e-01, -4.8846e-03,  3.1696e-01,  1.5057e-01,
#         -4.6451e-03, -1.9438e-01,  4.6736e-03,  2.7699e-01,  1.3359e-01,
#          8.4713e-05,  1.9513e-01, -3.0895e-03, -2.9278e-01,  1.1977e-01,
#         -3.8186e-03, -1.9530e-01,  2.7826e-03,  2.9657e-01,  1.1977e-01,
#         -4.8662e-03,  1.9504e-01,  6.1557e-03, -2.9095e-01,  1.5057e-01,
#          1.0623e-02, -1.9475e-01, -1.4610e-02,  2.8428e-01,  1.5057e-01])

# %%
agent.memory.sample(10)
# Out:
# [Transition(state=tensor([ 4.4670e-04, -1.9498e-01, -1.5388e-04,  2.8946e-01,  9.3057e-02]), action=tensor([[1]]), next_state=tensor([-0.0035,  0.1951,  0.0056, -0.2930,  0.0931]), reward=tensor([1.])),
#  Transition(state=tensor([-0.0035,  0.1951,  0.0056, -0.2913,  0.0931]), action=tensor([[1]]), next_state=tensor([ 4.4999e-04,  1.9498e-01, -2.2650e-04, -2.8953e-01,  9.3057e-02]), reward=tensor([1.])),
#  Transition(state=tensor([ 0.0067,  0.1963, -0.0082, -0.3198,  0.1506]), action=tensor([[0]]), next_state=tensor([ 0.0106, -0.1947, -0.0146,  0.2843,  0.1506]), reward=tensor([1.])),
#  Transition(state=tensor([-0.0039,  0.1956,  0.0047, -0.3042,  0.1198]), action=tensor([[1]]), next_state=tensor([ 8.4305e-06,  1.9557e-01, -1.4067e-03, -3.0270e-01,  1.1977e-01]), reward=tensor([1.])),
#  Transition(state=tensor([-0.0078,  0.1958,  0.0094, -0.3078,  0.1198]), action=tensor([[0]]), next_state=tensor([-0.0038, -0.1949,  0.0032,  0.2888,  0.1198]), reward=tensor([1.])),
#  Transition(state=tensor([ 4.4999e-04,  1.9498e-01, -2.2650e-04, -2.8953e-01,  9.3057e-02]), action=tensor([[0]]), next_state=tensor([ 0.0043, -0.1951, -0.0060,  0.2928,  0.0931]), reward=tensor([1.])),
#  Transition(state=tensor([ 0.0030,  0.1952, -0.0059, -0.2952,  0.0500]), action=tensor([[1]]), next_state=tensor([ 0.0069,  0.1953, -0.0118, -0.2968,  0.0500]), reward=tensor([1.])),
#  Transition(state=tensor([-0.0010,  0.1949,  0.0003, -0.2888,  0.1506]), action=tensor([[0]]), next_state=tensor([ 0.0029, -0.1963, -0.0054,  0.3184,  0.1506]), reward=tensor([1.])),
#  Transition(state=tensor([ 0.0029, -0.1962, -0.0049,  0.3170,  0.1506]), action=tensor([[1]]), next_state=tensor([-0.0010,  0.1951,  0.0015, -0.2919,  0.1506]), reward=tensor([1.])),
#  Transition(state=tensor([ 8.4305e-06,  1.9557e-01, -1.4067e-03, -3.0270e-01,  1.1977e-01]), action=tensor([[0]]), next_state=tensor([ 0.0039, -0.1950, -0.0075,  0.2907,  0.1198]), reward=tensor([1.]))]

# %%
# %debug
# Out:
# > c:\tools\anaconda3\lib\site-packages\torch\nn\functional.py(1370)linear()
#    1368     if input.dim() == 2 and bias is not None:
#    1369         # fused op is marginally faster
# -> 1370         ret = torch.addmm(bias, input, weight.t())
#    1371     else:
#    1372         output = input.matmul(weight.t())
#
# ipdb> u
# > c:\users\maxime\documents\cours_3a\object_recognition_and_cv\project\stable-nalu\stable_nalu\layer\basic.py(80)forward()
#      78         self.writer.add_scalar('W/sparsity_error', sparsity_error(self.W), verbose_only=False)
#      79         return self.activation_fn(
# ---> 80             torch.nn.functional.linear(input, self.W, self.bias)
#      81         )
#      82
#
# ipdb> u
# > c:\tools\anaconda3\lib\site-packages\torch\nn\modules\module.py(541)__call__()
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# ipdb> u
# > c:\users\maxime\documents\cours_3a\object_recognition_and_cv\project\stable-nalu\stable_nalu\layer\generalized.py(153)forward()
#     151
#     152     def forward(self, input):
# --> 153         return self.layer(input)
#     154
#     155     def extra_repr(self):
#
# ipdb> u
# > c:\tools\anaconda3\lib\site-packages\torch\nn\modules\module.py(541)__call__()
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# ipdb> u
# > c:\users\maxime\documents\cours_3a\object_recognition_and_cv\project\nau_rl.py(415)forward()
#     413             input = input[None]
#     414         for l in self.layers:
# --> 415             input = l(input)
#     416         z = input
#     417         return z
#
# ipdb> u
# > c:\tools\anaconda3\lib\site-packages\torch\nn\modules\module.py(541)__call__()
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# ipdb> u
# > c:\users\maxime\documents\cours_3a\object_recognition_and_cv\project\nau_rl.py(542)optimize_model()
#     540         # columns of actions taken. These are the actions which would've been taken
#     541         # for each batch state according to policy_net
# --> 542         state_action_values = self.Q(state_batch).gather(1, action_batch)
#     543
#     544         # Compute V(s_{t+1}) for all next states.
#
# ipdb> state_batch
# tensor([ 1.0711e-02,  1.9709e-01, -1.6635e-02, -3.4008e-01,  1.5057e-01,
#         -7.7245e-03,  1.9530e-01,  8.7141e-03, -2.9649e-01,  1.1977e-01,
#         -1.1865e-02,  1.9243e-01,  2.0106e-02, -2.3360e-01,  1.1977e-01,
#          4.4999e-04,  1.9498e-01, -2.2650e-04, -2.8953e-01,  9.3057e-02,
#         -3.4538e-03, -1.9504e-01,  5.6571e-03,  2.9086e-01,  9.3057e-02,
#         -7.7543e-03,  1.9477e-01,  9.3747e-03, -2.8489e-01,  1.1977e-01,
#          3.9199e-03, -1.9503e-01, -7.4606e-03,  2.9069e-01,  1.1977e-01,
#          2.8481e-03, -1.9575e-01, -3.5572e-03,  3.0647e-01,  1.5057e-01,
#          3.2706e-03, -1.9465e-01, -9.5011e-03,  2.8255e-01,  1.3359e-01,
#         -4.9808e-03, -1.9573e-01,  8.6785e-03,  3.0615e-01,  1.5057e-01,
#         -1.0162e-03,  1.9508e-01,  1.4546e-03, -2.9194e-01,  1.5057e-01,
#          6.7164e-03, -1.9619e-01, -8.6651e-03,  3.1647e-01,  1.5057e-01,
#          0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  9.3057e-02,
#          2.8854e-03,  1.9506e-01, -4.3842e-03, -2.9145e-01,  1.5057e-01,
#         -1.5724e-02,  1.9295e-01,  2.4966e-02, -2.4297e-01,  1.1977e-01,
#          7.0257e-03,  1.9513e-01, -1.2098e-02, -2.9269e-01,  1.3359e-01,
#         -9.4246e-04, -1.9619e-01, -1.7238e-04,  3.1640e-01,  1.5057e-01,
#          0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  5.0017e-02,
#         -7.7278e-03,  1.9546e-01,  8.7861e-03, -3.0018e-01,  1.1977e-01,
#          1.0593e-02,  1.9566e-01, -1.3934e-02, -3.0459e-01,  1.5057e-01,
#         -1.1698e-02,  1.9443e-01,  1.6157e-02, -2.7721e-01,  1.1977e-01,
#         -3.4528e-03,  1.9514e-01,  5.6353e-03, -2.9298e-01,  9.3057e-02,
#         -3.4576e-03,  1.9521e-01,  5.7406e-03, -2.9472e-01,  9.3057e-02,
#         -1.0669e-03, -1.9570e-01,  2.5722e-03,  3.0531e-01,  1.5057e-01,
#          1.0660e-02,  1.9669e-01, -1.5460e-02, -3.2935e-01,  1.5057e-01,
#          1.0623e-02, -1.9475e-01, -1.4610e-02,  2.8428e-01,  1.5057e-01,
#          2.8646e-03,  1.9529e-01, -3.9230e-03, -2.9639e-01,  1.5057e-01,
#          8.4305e-06,  1.9557e-01, -1.4067e-03, -3.0270e-01,  1.1977e-01,
#         -1.1297e-02, -1.9584e-01,  1.8227e-02,  3.1025e-01,  9.3057e-02,
#          6.6818e-03,  1.9555e-01, -7.8943e-03, -3.0200e-01,  1.5057e-01,
#          3.0081e-03,  1.9522e-01, -5.8731e-03, -2.9516e-01,  5.0017e-02,
#         -1.5261e-02,  1.9327e-01,  2.5582e-02, -2.4988e-01,  9.3057e-02,
#          1.4726e-02, -1.9360e-01, -2.3717e-02,  2.5776e-01,  5.0017e-02,
#         -7.7343e-03, -1.9533e-01,  8.9303e-03,  2.9731e-01,  1.1977e-01,
#          1.4652e-02,  1.9716e-01, -2.3437e-02, -3.4452e-01,  1.5057e-01,
#         -7.3820e-03, -1.9573e-01,  1.2092e-02,  3.0674e-01,  9.3057e-02,
#         -1.1641e-02,  1.9518e-01,  1.4877e-02, -2.9378e-01,  1.1977e-01,
#         -4.5760e-03,  1.9619e-01,  3.1423e-03, -3.1656e-01,  1.3359e-01,
#         -3.4688e-03, -1.9566e-01,  5.9929e-03,  3.0498e-01,  9.3057e-02,
#         -1.1257e-02,  1.9483e-01,  1.7327e-02, -2.8614e-01,  9.3057e-02,
#         -8.8954e-03,  1.9541e-01,  1.4801e-02, -2.9882e-01,  1.5057e-01,
#          1.0854e-02,  1.9583e-01, -1.8562e-02, -3.1167e-01,  5.0017e-02,
#         -8.9634e-04,  1.9522e-01,  3.0350e-05, -2.9517e-01,  5.0017e-02,
#         -9.6551e-04,  1.9493e-01,  3.3659e-04, -2.8884e-01,  1.5057e-01,
#         -1.1736e-02, -1.9640e-01,  1.7019e-02,  3.2330e-01,  1.1977e-01,
#          1.0600e-02, -1.9591e-01, -1.4102e-02,  3.1039e-01,  1.5057e-01,
#          1.0598e-02, -1.9510e-01, -1.4052e-02,  2.9193e-01,  1.5057e-01,
#         -4.9873e-03,  1.9517e-01,  8.8250e-03, -2.9385e-01,  1.5057e-01,
#          4.3045e-04, -1.9480e-01,  2.0468e-04,  2.8569e-01,  9.3057e-02,
#         -7.7505e-04,  1.9501e-01, -4.7745e-04, -2.9042e-01,  1.3359e-01,
#         -1.0838e-03,  1.9503e-01,  2.9481e-03, -2.9084e-01,  1.5057e-01,
#         -7.7781e-03, -1.9600e-01,  9.9061e-03,  3.1256e-01,  1.1977e-01,
#         -1.9594e-02,  1.9353e-01,  3.0046e-02, -2.5399e-01,  1.1977e-01,
#         -7.7378e-03,  1.9563e-01,  9.0088e-03, -3.0393e-01,  1.1977e-01,
#         -7.5399e-03, -1.9693e-01,  1.5770e-02,  3.3956e-01,  9.3057e-02,
#          4.4703e-04, -1.9504e-01, -1.6115e-04,  2.9091e-01,  9.3057e-02,
#          1.0818e-02,  1.9539e-01, -1.7713e-02, -3.0019e-01,  5.0017e-02,
#         -1.1478e-02, -1.9694e-01,  2.2561e-02,  3.4330e-01,  9.3057e-02,
#          2.8168e-03,  1.9498e-01, -2.8686e-03, -2.8983e-01,  1.5057e-01,
#         -4.8662e-03,  1.9504e-01,  6.1557e-03, -2.9095e-01,  1.5057e-01,
#          1.0927e-02, -1.9501e-01, -1.7932e-02,  2.8977e-01,  1.3359e-01,
#          1.4594e-02, -1.9417e-01, -2.2047e-02,  2.7057e-01,  1.5057e-01,
#         -7.3546e-03, -1.9512e-01,  1.1474e-02,  2.9263e-01,  9.3057e-02,
#          0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  1.1977e-01,
#         -1.0630e-03,  1.9555e-01,  2.4865e-03, -3.0219e-01,  1.5057e-01,
#          2.9332e-03, -1.9627e-01, -5.4402e-03,  3.1837e-01,  1.5057e-01,
#          4.4670e-04, -1.9498e-01, -1.5388e-04,  2.8946e-01,  9.3057e-02,
#          1.0928e-02,  1.9531e-01, -1.7951e-02, -2.9667e-01,  1.3359e-01,
#          0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  1.5057e-01,
#          6.7704e-03, -1.9590e-01, -9.8508e-03,  3.1002e-01,  1.5057e-01,
#          6.7276e-03,  1.9662e-01, -8.9247e-03, -3.2675e-01,  1.5057e-01,
#          6.7866e-03, -1.9610e-01, -1.0213e-02,  3.1450e-01,  1.5057e-01,
#          3.9333e-03, -1.9489e-01, -7.7562e-03,  2.8770e-01,  1.1977e-01,
#         -6.5229e-04,  1.9615e-01, -3.1890e-03, -3.1561e-01,  1.3359e-01,
#          1.8596e-02,  1.9722e-01, -3.0327e-02, -3.5051e-01,  1.5057e-01,
#         -3.8589e-03, -1.9596e-01,  3.6769e-03,  3.1146e-01,  1.1977e-01,
#         -6.2247e-04, -1.9449e-01, -3.8500e-03,  2.7928e-01,  1.3359e-01,
#         -3.4512e-03,  1.9506e-01,  5.5993e-03, -2.9129e-01,  9.3057e-02,
#         -8.5327e-03,  1.9632e-01,  1.0213e-02, -3.2001e-01,  1.3359e-01,
#         -3.8600e-03, -1.9474e-01,  3.7004e-03,  2.8446e-01,  1.1977e-01,
#         -1.1335e-02, -1.9630e-01,  1.9136e-02,  3.2232e-01,  9.3057e-02,
#          2.9081e-03, -1.9621e-01, -4.8846e-03,  3.1696e-01,  1.5057e-01,
#         -4.6451e-03, -1.9438e-01,  4.6736e-03,  2.7699e-01,  1.3359e-01,
#         -3.8186e-03,  1.9517e-01,  2.7842e-03, -2.9369e-01,  1.1977e-01,
#         -3.8252e-03, -1.9513e-01,  2.9303e-03,  2.9279e-01,  1.1977e-01,
#         -1.5664e-02, -1.9652e-01,  2.3485e-02,  3.2803e-01,  1.1977e-01,
#         -7.3603e-03,  1.9457e-01,  1.1604e-02, -2.8056e-01,  9.3057e-02,
#          6.6960e-03,  1.9521e-01, -8.2109e-03, -2.9455e-01,  1.5057e-01,
#          3.9872e-03, -1.9546e-01, -8.9452e-03,  3.0014e-01,  1.1977e-01,
#         -4.4224e-06, -1.9500e-01, -1.1232e-03,  2.8998e-01,  1.1977e-01,
#         -1.1395e-02,  1.9278e-01,  2.0585e-02, -2.4073e-01,  9.3057e-02,
#          2.7927e-03,  1.9516e-01, -2.3358e-03, -2.9376e-01,  1.5057e-01,
#          3.5374e-05, -1.9477e-01, -2.0021e-03,  2.8513e-01,  1.1977e-01,
#         -3.8384e-03, -1.9579e-01,  3.2225e-03,  3.0761e-01,  1.1977e-01,
#         -4.6064e-03,  1.9620e-01,  3.8131e-03, -3.1695e-01,  1.3359e-01,
#          7.8062e-05, -1.9533e-01, -2.9425e-03,  2.9729e-01,  1.1977e-01,
#          4.4028e-04, -1.9489e-01, -1.2362e-05,  2.8765e-01,  9.3057e-02,
#          3.1329e-03, -1.9451e-01, -6.4627e-03,  2.7953e-01,  1.3359e-01,
#         -9.9226e-04,  1.9502e-01,  9.2713e-04, -2.9059e-01,  1.5057e-01,
#          1.4835e-02,  1.9634e-01, -2.6414e-02, -3.3065e-01,  5.0017e-02,
#          1.4834e-02, -1.9536e-01, -2.3885e-02,  2.9764e-01,  1.3359e-01,
#          7.0272e-03, -1.9471e-01, -1.2137e-02,  2.8370e-01,  1.3359e-01,
#         -3.9183e-03,  1.9569e-01,  4.9840e-03, -3.0536e-01,  1.1977e-01,
#          1.4771e-02,  1.9593e-01, -2.4795e-02, -3.1652e-01,  5.0017e-02,
#         -7.5723e-04, -1.9439e-01, -8.7214e-04,  2.7729e-01,  1.3359e-01,
#         -3.8389e-03, -1.9494e-01,  3.2329e-03,  2.8879e-01,  1.1977e-01,
#         -3.9043e-03,  1.9564e-01,  4.6765e-03, -3.0416e-01,  1.1977e-01,
#          1.4506e-02, -1.9541e-01, -2.0026e-02,  2.9868e-01,  1.5057e-01,
#         -7.8094e-03, -1.9631e-01,  1.0613e-02,  3.2029e-01,  1.1977e-01,
#         -3.8186e-03, -1.9530e-01,  2.7826e-03,  2.9657e-01,  1.1977e-01,
#          4.3496e-03, -1.9513e-01, -6.0171e-03,  2.9280e-01,  9.3057e-02,
#          4.4989e-04, -1.9505e-01, -2.2437e-04,  2.9119e-01,  9.3057e-02,
#         -1.9612e-05, -1.9493e-01, -7.8809e-04,  2.8861e-01,  1.1977e-01,
#          3.1252e-03,  1.9502e-01, -6.2860e-03, -2.9059e-01,  1.3359e-01,
#         -6.8231e-04, -1.9469e-01, -2.5260e-03,  2.8342e-01,  1.3359e-01,
#          2.8523e-03, -1.9577e-01, -3.6504e-03,  3.0685e-01,  1.5057e-01,
#          1.9301e-05,  1.9570e-01, -1.6468e-03, -3.0547e-01,  1.1977e-01,
#         -1.5213e-02,  1.9393e-01,  2.4432e-02, -2.6481e-01,  9.3057e-02,
#          6.6959e-03,  1.9633e-01, -8.2138e-03, -3.1983e-01,  1.5057e-01,
#          1.8689e-02, -1.9273e-01, -3.1126e-02,  2.3557e-01,  5.0017e-02,
#         -3.4656e-03,  1.9529e-01,  5.9186e-03, -2.9655e-01,  9.3057e-02,
#          0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  1.3359e-01,
#         -3.8286e-03, -1.9529e-01,  3.0033e-03,  2.9635e-01,  1.1977e-01,
#          8.4713e-05,  1.9513e-01, -3.0895e-03, -2.9278e-01,  1.1977e-01,
#          6.9125e-03,  1.9528e-01, -1.1776e-02, -2.9685e-01,  5.0017e-02,
#         -7.7375e-03,  1.9495e-01,  9.0010e-03, -2.8893e-01,  1.1977e-01,
#         -7.7548e-03,  1.9580e-01,  9.3897e-03, -3.0784e-01,  1.1977e-01,
#         -4.5123e-03,  1.9636e-01,  1.7355e-03, -3.2060e-01,  1.3359e-01])
# ipdb> state_batch[0]
# tensor(0.0107)
# ipdb> exit

# %%
agent.evaluate((0.1, 0.1), render=True)
# Out:
# <video alt="gym-results\openaigym.video.7.3120.video000000.mp4" autoplay
#                       loop controls style="height: 400px;">
#                       <source src="data:video/mp4;base64,..." type="video/mp4" />
#                  </video>
# Reward: 38.0
# masspole : 0.10
# 38.0

# %%
np.linalg.eig(np.array([[1, -1], [1, -1]]))
# Out:
# (array([3.25176795e-17+1.57009246e-16j, 3.25176795e-17-1.57009246e-16j]),
#  array([[0.70710678+1.11022302e-16j, 0.70710678-1.11022302e-16j],
#         [0.70710678+0.00000000e+00j, 0.70710678-0.00000000e+00j]]))
