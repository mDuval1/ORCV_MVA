# %%
# %matplotlib notebook
# %load_ext autoreload
# %autoreload 2

# %%
import tqdm

import stable_nalu

from RLfunctions import *
from NAU_RL import *

# %%
import os
import os.path as path

# %% [markdown]
# # Tests

# %%
l = stable_nalu.layer.ReRegualizedLinearNALULayer(10, 20, nalu_gate='add', nalu_mul='normal', nalu_two_nac=True)
l2 = stable_nalu.layer.ReRegualizedLinearNALULayer(10, 20, nalu_mul='normal', nalu_two_nac=True)

# %%
l.nac_add, l2.nac_add
# Out:
# (ReRegualizedLinearNACLayer(in_features=10, out_features=20),
#  ReRegualizedLinearNACLayer(in_features=10, out_features=20))

# %%
l.nac_mul, l2.nac_mul
# Out:
# (ReRegualizedLinearNACLayer(in_features=10, out_features=20),
#  ReRegualizedLinearNACLayer(in_features=10, out_features=20))

# %%
x = torch.rand(5, 10)

# %%
l(x)
# Out:
# tensor([[   nan, 1.0000, 1.0000, 1.0000, 2.0139, 2.8186, 4.6413, 5.2121, 6.2189,
#          4.7100, 3.4492, 4.4482, 5.7615, 3.7511, 4.0242, 4.3408, 4.3938, 4.3485,
#          6.3058, 6.3058],
#         [   nan, 1.0000, 1.0000, 1.0000, 1.4002, 3.4067, 4.5266, 4.5348, 4.4313,
#          3.1746, 3.1171, 3.2783, 4.1157, 3.1767, 1.8870, 3.8158, 2.2758, 3.3661,
#          4.5794, 4.5794],
#         [   nan, 1.0000, 1.0000, 1.0000, 2.8060, 2.7654, 5.2567, 6.1742, 7.8815,
#          5.4048, 4.0791, 5.9458, 7.2538, 4.9040, 6.0764, 5.6560, 6.1232, 5.1386,
#          8.0445, 8.0445],
#         [   nan, 1.0000, 1.0000, 1.0000, 1.8112, 2.5284, 4.4726, 4.6909, 4.5174,
#          3.4005, 3.0346, 4.1649, 4.4230, 3.9047, 3.8035, 3.7324, 3.3196, 3.3679,
#          5.2123, 5.2123],
#         [   nan, 1.0000, 1.0000, 1.0000, 2.3478, 1.8355, 4.4496, 4.8279, 4.8643,
#          3.4414, 3.3712, 3.4121, 5.1523, 3.6356, 5.3273, 3.8591, 4.7041, 3.6193,
#          5.8199, 5.8199]], grad_fn=<AddBackward0>)

# %%
l2(x)
# Out:
# tensor([[9.7067e-03, 8.8365e-04, 6.4164e-03, 2.0423e-03, 1.3288e-02, 6.0581e-04,
#          4.2084e-03, 4.6207e-04, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#          1.9150e-03, 7.4024e-03, 3.5877e-03, 3.7344e-03, 1.5695e-03, 1.4161e-02,
#          9.2965e-04, 4.7954e-03],
#         [6.5409e-05, 8.7069e-07, 2.5666e-03, 8.1010e-08, 1.3514e-04, 1.4054e-07,
#          1.7604e-07, 3.1634e-08, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#          7.6650e-07, 3.5954e-06, 1.0318e-06, 1.3167e-05, 1.3455e-07, 2.2470e-05,
#          8.0093e-08, 1.1614e-05],
#         [1.6633e-02, 6.5954e-03, 3.6593e-02, 3.2272e-02, 4.7422e-02, 9.2474e-03,
#          3.0397e-02, 6.2847e-03, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#          3.1991e-02, 7.0955e-02, 1.8170e-02, 1.5077e-02, 8.2204e-03, 2.0820e-02,
#          9.4965e-03, 1.0779e-01],
#         [1.4559e-03, 5.1215e-05, 1.9834e-03, 8.0733e-05, 5.6435e-04, 9.0529e-05,
# ...

# %% [markdown]
# # Addition

# %% [markdown]
# Only NAU : works on addition

# %%
# %run stable-nalu/experiments/simple_function_static.py --operation=add --max-iterations=50000 \
            --layer-type=ReRegualizedLinearNAC \
            --input-size=10 --regualizer=1
# Out:
# running
#   - layer_type: ReRegualizedLinearNAC
#   - first_layer: None
#   - operation: add
#   - num_subsets: 2
#   - regualizer: 1.0
#   - regualizer_z: 0
#   - regualizer_oob: 1
#   -
#   - max_iterations: 50000
#   - batch_size: 128
#   - seed: 0
#   -
#   - interpolation_range: [1, 2]
#   - extrapolation_range: [2, 6]
#   - input_size: 10
#   - subset_ratio: 0.25
#   - overlap_ratio: 0.5
#   - simple: False
#   -
#   - hidden_size: 2
#   - nac_mul: none
#   - oob_mode: clip
#   - regualizer_scaling: linear
#   - regualizer_scaling_start: 1000000
#   - regualizer_scaling_end: 2000000
#   - regualizer_shape: linear
#   - mnac_epsilon: 0
#   - nalu_bias: False
#   - nalu_two_nac: False
#   - nalu_two_gate: False
#   - nalu_mul: normal
#   - nalu_gate: normal
#   -
#   - optimizer: adam
#   - learning_rate: 0.001
#   - momentum: 0.0
#   -
#   - cuda: True
#   - name_prefix: simple_function_static
#   - remove_existing_data: False
#   - verbose: False
#   -
# ...

# %% [markdown]
# NALU with addition

# %%
# %run stable-nalu/experiments/simple_function_static.py --operation=add --max-iterations=50000 \
            --layer-type=ReRegualizedLinearNALU --nalu-two-nac --nalu-mul=normal --nalu-gate=add \
            --input-size=10 --regualizer=1
# Out:
# running
#   - layer_type: ReRegualizedLinearNALU
#   - first_layer: None
#   - operation: add
#   - num_subsets: 2
#   - regualizer: 1.0
#   - regualizer_z: 0
#   - regualizer_oob: 1
#   -
#   - max_iterations: 50000
#   - batch_size: 128
#   - seed: 0
#   -
#   - interpolation_range: [1, 2]
#   - extrapolation_range: [2, 6]
#   - input_size: 10
#   - subset_ratio: 0.25
#   - overlap_ratio: 0.5
#   - simple: False
#   -
#   - hidden_size: 2
#   - nac_mul: none
#   - oob_mode: clip
#   - regualizer_scaling: linear
#   - regualizer_scaling_start: 1000000
#   - regualizer_scaling_end: 2000000
#   - regualizer_shape: linear
#   - mnac_epsilon: 0
#   - nalu_bias: False
#   - nalu_two_nac: True
#   - nalu_two_gate: False
#   - nalu_mul: normal
#   - nalu_gate: add
#   -
#   - optimizer: adam
#   - learning_rate: 0.001
#   - momentum: 0.0
#   -
#   - cuda: True
#   - name_prefix: simple_function_static
#   - remove_existing_data: False
#   - verbose: False
#   -
# ...

# %% [markdown]
# NALU with gating (Control)

# %%
# %run stable-nalu/experiments/simple_function_static.py --operation=add --max-iterations=50000 \
            --layer-type=ReRegualizedLinearNALU --nalu-two-nac --nalu-mul=normal \
            --input-size=10 --regualizer=1
# Out:
# running
#   - layer_type: ReRegualizedLinearNALU
#   - first_layer: None
#   - operation: add
#   - num_subsets: 2
#   - regualizer: 1.0
#   - regualizer_z: 0
#   - regualizer_oob: 1
#   -
#   - max_iterations: 50000
#   - batch_size: 128
#   - seed: 0
#   -
#   - interpolation_range: [1, 2]
#   - extrapolation_range: [2, 6]
#   - input_size: 10
#   - subset_ratio: 0.25
#   - overlap_ratio: 0.5
#   - simple: False
#   -
#   - hidden_size: 2
#   - nac_mul: none
#   - oob_mode: clip
#   - regualizer_scaling: linear
#   - regualizer_scaling_start: 1000000
#   - regualizer_scaling_end: 2000000
#   - regualizer_shape: linear
#   - mnac_epsilon: 0
#   - nalu_bias: False
#   - nalu_two_nac: True
#   - nalu_two_gate: False
#   - nalu_mul: normal
#   - nalu_gate: normal
#   -
#   - optimizer: adam
#   - learning_rate: 0.001
#   - momentum: 0.0
#   -
#   - cuda: True
#   - name_prefix: simple_function_static
#   - remove_existing_data: False
#   - verbose: False
#   -
# ...

# %% [markdown]
# NALU with two gates

# %%
# %run stable-nalu/experiments/simple_function_static.py --operation=add --max-iterations=50000 \
            --layer-type=ReRegualizedLinearNALU --nalu-two-nac --nalu-mul=normal --nalu-two-gate \
            --input-size=10 --regualizer=1
# Out:
# running
#   - layer_type: ReRegualizedLinearNALU
#   - first_layer: None
#   - operation: add
#   - num_subsets: 2
#   - regualizer: 1.0
#   - regualizer_z: 0
#   - regualizer_oob: 1
#   -
#   - max_iterations: 50000
#   - batch_size: 128
#   - seed: 0
#   -
#   - interpolation_range: [1, 2]
#   - extrapolation_range: [2, 6]
#   - input_size: 10
#   - subset_ratio: 0.25
#   - overlap_ratio: 0.5
#   - simple: False
#   -
#   - hidden_size: 2
#   - nac_mul: none
#   - oob_mode: clip
#   - regualizer_scaling: linear
#   - regualizer_scaling_start: 1000000
#   - regualizer_scaling_end: 2000000
#   - regualizer_shape: linear
#   - mnac_epsilon: 0
#   - nalu_bias: False
#   - nalu_two_nac: True
#   - nalu_two_gate: True
#   - nalu_mul: normal
#   - nalu_gate: normal
#   -
#   - optimizer: adam
#   - learning_rate: 0.001
#   - momentum: 0.0
#   -
#   - cuda: True
#   - name_prefix: simple_function_static
#   - remove_existing_data: False
#   - verbose: False
#   -
# ...

# %% [markdown]
# Original NALU (NAC., NAC+)

# %%
# %run stable-nalu/experiments/simple_function_static.py --operation=add --max-iterations=50000 \
            --layer-type=NALU --nalu-two-nac --nalu-mul=normal \
            --input-size=10 --regualizer=1
# Out:
# running
#   - layer_type: NALU
#   - first_layer: None
#   - operation: add
#   - num_subsets: 2
#   - regualizer: 1.0
#   - regualizer_z: 0
#   - regualizer_oob: 1
#   -
#   - max_iterations: 50000
#   - batch_size: 128
#   - seed: 0
#   -
#   - interpolation_range: [1, 2]
#   - extrapolation_range: [2, 6]
#   - input_size: 10
#   - subset_ratio: 0.25
#   - overlap_ratio: 0.5
#   - simple: False
#   -
#   - hidden_size: 2
#   - nac_mul: none
#   - oob_mode: clip
#   - regualizer_scaling: linear
#   - regualizer_scaling_start: 1000000
#   - regualizer_scaling_end: 2000000
#   - regualizer_shape: linear
#   - mnac_epsilon: 0
#   - nalu_bias: False
#   - nalu_two_nac: True
#   - nalu_two_gate: False
#   - nalu_mul: normal
#   - nalu_gate: normal
#   -
#   - optimizer: adam
#   - learning_rate: 0.001
#   - momentum: 0.0
#   -
#   - cuda: True
#   - name_prefix: simple_function_static
#   - remove_existing_data: False
#   - verbose: False
#   -
#   - dataset: sum(v[4:6]) + sum(v[5:7])
#
# ...

# %% [markdown]
# NALU shared

# %%
# %run stable-nalu/experiments/simple_function_static.py --operation=add --max-iterations=50000 \
            --layer-type=NALU --nalu-mul=normal \
            --input-size=10 --regualizer=1
# Out:
# running
#   - layer_type: NALU
#   - first_layer: None
#   - operation: add
#   - num_subsets: 2
#   - regualizer: 1.0
#   - regualizer_z: 0
#   - regualizer_oob: 1
#   -
#   - max_iterations: 50000
#   - batch_size: 128
#   - seed: 0
#   -
#   - interpolation_range: [1, 2]
#   - extrapolation_range: [2, 6]
#   - input_size: 10
#   - subset_ratio: 0.25
#   - overlap_ratio: 0.5
#   - simple: False
#   -
#   - hidden_size: 2
#   - nac_mul: none
#   - oob_mode: clip
#   - regualizer_scaling: linear
#   - regualizer_scaling_start: 1000000
#   - regualizer_scaling_end: 2000000
#   - regualizer_shape: linear
#   - mnac_epsilon: 0
#   - nalu_bias: False
#   - nalu_two_nac: False
#   - nalu_two_gate: False
#   - nalu_mul: normal
#   - nalu_gate: normal
#   -
#   - optimizer: adam
#   - learning_rate: 0.001
#   - momentum: 0.0
#   -
#   - cuda: True
#   - name_prefix: simple_function_static
#   - remove_existing_data: False
#   - verbose: False
#   -
#   - dataset: sum(v[4:6]) + sum(v[5:7])
# ...

# %% [markdown]
# # Multiplication

# %% [markdown]
# Only NMU : works on addition

# %%
# %run stable-nalu/experiments/simple_function_static.py --operation=mul --max-iterations=50000 \
            --layer-type=ReRegualizedLinearNAC --nac-mul=mnac \
            --input-size=10 --regualizer=1
# Out:
# running
#   - layer_type: ReRegualizedLinearNAC
#   - first_layer: None
#   - operation: mul
#   - num_subsets: 2
#   - regualizer: 1.0
#   - regualizer_z: 0
#   - regualizer_oob: 1
#   -
#   - max_iterations: 50000
#   - batch_size: 128
#   - seed: 0
#   -
#   - interpolation_range: [1, 2]
#   - extrapolation_range: [2, 6]
#   - input_size: 10
#   - subset_ratio: 0.25
#   - overlap_ratio: 0.5
#   - simple: False
#   -
#   - hidden_size: 2
#   - nac_mul: mnac
#   - oob_mode: clip
#   - regualizer_scaling: linear
#   - regualizer_scaling_start: 1000000
#   - regualizer_scaling_end: 2000000
#   - regualizer_shape: linear
#   - mnac_epsilon: 0
#   - nalu_bias: False
#   - nalu_two_nac: False
#   - nalu_two_gate: False
#   - nalu_mul: normal
#   - nalu_gate: normal
#   -
#   - optimizer: adam
#   - learning_rate: 0.001
#   - momentum: 0.0
#   -
#   - cuda: True
#   - name_prefix: simple_function_static
#   - remove_existing_data: False
#   - verbose: False
#   -
# ...

# %% [markdown]
# NALU with addition

# %%
# %run stable-nalu/experiments/simple_function_static.py --operation=mul --max-iterations=50000 \
            --layer-type=ReRegualizedLinearNALU --nalu-two-nac --nalu-mul=normal --nalu-gate=add \
            --input-size=10 --regualizer=0.01
# Out:
# running
#   - layer_type: ReRegualizedLinearNALU
#   - first_layer: None
#   - operation: mul
#   - num_subsets: 2
#   - regualizer: 0.01
#   - regualizer_z: 0
#   - regualizer_oob: 1
#   -
#   - max_iterations: 50000
#   - batch_size: 128
#   - seed: 0
#   -
#   - interpolation_range: [1, 2]
#   - extrapolation_range: [2, 6]
#   - input_size: 10
#   - subset_ratio: 0.25
#   - overlap_ratio: 0.5
#   - simple: False
#   -
#   - hidden_size: 2
#   - nac_mul: none
#   - oob_mode: clip
#   - regualizer_scaling: linear
#   - regualizer_scaling_start: 1000000
#   - regualizer_scaling_end: 2000000
#   - regualizer_shape: linear
#   - mnac_epsilon: 0
#   - nalu_bias: False
#   - nalu_two_nac: True
#   - nalu_two_gate: False
#   - nalu_mul: normal
#   - nalu_gate: add
#   -
#   - optimizer: adam
#   - learning_rate: 0.001
#   - momentum: 0.0
#   -
#   - cuda: True
#   - name_prefix: simple_function_static
#   - remove_existing_data: False
#   - verbose: False
#   -
# ...

# %% [markdown]
# NALU with gating (control)

# %%
# %run stable-nalu/experiments/simple_function_static.py --operation=mul --max-iterations=50000 \
            --layer-type=ReRegualizedLinearNALU --nalu-two-nac --nalu-mul=normal \
            --input-size=10 --regualizer=1
# Out:
# running
#   - layer_type: ReRegualizedLinearNALU
#   - first_layer: None
#   - operation: mul
#   - num_subsets: 2
#   - regualizer: 1.0
#   - regualizer_z: 0
#   - regualizer_oob: 1
#   -
#   - max_iterations: 50000
#   - batch_size: 128
#   - seed: 0
#   -
#   - interpolation_range: [1, 2]
#   - extrapolation_range: [2, 6]
#   - input_size: 10
#   - subset_ratio: 0.25
#   - overlap_ratio: 0.5
#   - simple: False
#   -
#   - hidden_size: 2
#   - nac_mul: none
#   - oob_mode: clip
#   - regualizer_scaling: linear
#   - regualizer_scaling_start: 1000000
#   - regualizer_scaling_end: 2000000
#   - regualizer_shape: linear
#   - mnac_epsilon: 0
#   - nalu_bias: False
#   - nalu_two_nac: True
#   - nalu_two_gate: False
#   - nalu_mul: normal
#   - nalu_gate: normal
#   -
#   - optimizer: adam
#   - learning_rate: 0.001
#   - momentum: 0.0
#   -
#   - cuda: True
#   - name_prefix: simple_function_static
#   - remove_existing_data: False
#   - verbose: False
#   -
# ...

# %% [markdown]
# NALU with two gates

# %%
# %run stable-nalu/experiments/simple_function_static.py --operation=mul --max-iterations=50000 \
            --layer-type=ReRegualizedLinearNALU --nalu-two-nac --nalu-mul=normal --nalu-two-gate \
            --input-size=10 --regualizer=1
# Out:
# running
#   - layer_type: ReRegualizedLinearNALU
#   - first_layer: None
#   - operation: mul
#   - num_subsets: 2
#   - regualizer: 1.0
#   - regualizer_z: 0
#   - regualizer_oob: 1
#   -
#   - max_iterations: 50000
#   - batch_size: 128
#   - seed: 0
#   -
#   - interpolation_range: [1, 2]
#   - extrapolation_range: [2, 6]
#   - input_size: 10
#   - subset_ratio: 0.25
#   - overlap_ratio: 0.5
#   - simple: False
#   -
#   - hidden_size: 2
#   - nac_mul: none
#   - oob_mode: clip
#   - regualizer_scaling: linear
#   - regualizer_scaling_start: 1000000
#   - regualizer_scaling_end: 2000000
#   - regualizer_shape: linear
#   - mnac_epsilon: 0
#   - nalu_bias: False
#   - nalu_two_nac: True
#   - nalu_two_gate: True
#   - nalu_mul: normal
#   - nalu_gate: normal
#   -
#   - optimizer: adam
#   - learning_rate: 0.001
#   - momentum: 0.0
#   -
#   - cuda: True
#   - name_prefix: simple_function_static
#   - remove_existing_data: False
#   - verbose: False
#   -
# ...

# %% [markdown]
# Original NALU (NAC., NAC+)

# %%
# %run stable-nalu/experiments/simple_function_static.py --operation=mul --max-iterations=50000 \
            --layer-type=NALU --nalu-two-nac --nalu-mul=normal \
            --input-size=10 --regualizer=1
# Out:
# running
#   - layer_type: NALU
#   - first_layer: None
#   - operation: mul
#   - num_subsets: 2
#   - regualizer: 1.0
#   - regualizer_z: 0
#   - regualizer_oob: 1
#   -
#   - max_iterations: 50000
#   - batch_size: 128
#   - seed: 0
#   -
#   - interpolation_range: [1, 2]
#   - extrapolation_range: [2, 6]
#   - input_size: 10
#   - subset_ratio: 0.25
#   - overlap_ratio: 0.5
#   - simple: False
#   -
#   - hidden_size: 2
#   - nac_mul: none
#   - oob_mode: clip
#   - regualizer_scaling: linear
#   - regualizer_scaling_start: 1000000
#   - regualizer_scaling_end: 2000000
#   - regualizer_shape: linear
#   - mnac_epsilon: 0
#   - nalu_bias: False
#   - nalu_two_nac: True
#   - nalu_two_gate: False
#   - nalu_mul: normal
#   - nalu_gate: normal
#   -
#   - optimizer: adam
#   - learning_rate: 0.001
#   - momentum: 0.0
#   -
#   - cuda: True
#   - name_prefix: simple_function_static
#   - remove_existing_data: False
#   - verbose: False
#   -
#   - dataset: sum(v[4:6]) * sum(v[5:7])
#
# ...

# %% [markdown]
# NALU shared

# %%
# %run stable-nalu/experiments/simple_function_static.py --operation=mul --max-iterations=50000 \
            --layer-type=NALU --nalu-mul=normal \
            --input-size=10 --regualizer=1
# Out:
# running
#   - layer_type: NALU
#   - first_layer: None
#   - operation: mul
#   - num_subsets: 2
#   - regualizer: 1.0
#   - regualizer_z: 0
#   - regualizer_oob: 1
#   -
#   - max_iterations: 50000
#   - batch_size: 128
#   - seed: 0
#   -
#   - interpolation_range: [1, 2]
#   - extrapolation_range: [2, 6]
#   - input_size: 10
#   - subset_ratio: 0.25
#   - overlap_ratio: 0.5
#   - simple: False
#   -
#   - hidden_size: 2
#   - nac_mul: none
#   - oob_mode: clip
#   - regualizer_scaling: linear
#   - regualizer_scaling_start: 1000000
#   - regualizer_scaling_end: 2000000
#   - regualizer_shape: linear
#   - mnac_epsilon: 0
#   - nalu_bias: False
#   - nalu_two_nac: False
#   - nalu_two_gate: False
#   - nalu_mul: normal
#   - nalu_gate: normal
#   -
#   - optimizer: adam
#   - learning_rate: 0.001
#   - momentum: 0.0
#   -
#   - cuda: True
#   - name_prefix: simple_function_static
#   - remove_existing_data: False
#   - verbose: False
#   -
#   - dataset: sum(v[4:6]) * sum(v[5:7])
# ...
